# %%
# 1. 라이브러리 import
import random # random 수 생성
import pandas as pd # 데이터 처리/분석
import numpy as np # 행렬, 배열 연산
import os # 운영체제 관련 기능 사용
import cv2 # 이미지 처리

# 사이킷런
from sklearn import preprocessing # 데이터 전처리
from sklearn.model_selection import train_test_split # 데이터 분할

# 파이토치
import torch
import torch.nn as nn # 신경망
import torch.optim as optim # 최적화
import torch.nn.functional as F # 신경망 연산
from torch.utils.data import Dataset, DataLoader # 데이터 사용 (Dataset - 샘플과 정답(label)을 저장, DataLoader - Dataset 을 샘플에 쉽게 접근할 수 있도록)

from tqdm.auto import tqdm # 진행바 깔끔 출력

import albumentations as A # 이미지 증강 ### https://hoya012.github.io/blog/albumentation_tutorial/ 다른 이미지 증강법 쓰면?
from albumentations.pytorch.transforms import ToTensorV2 # 파이토치 호환

import torchvision.models as models # pretrained 모델 사용 (efficientnet)

from sklearn.metrics import f1_score # 모델 평가 지표인 f1 사용

import warnings # 경고 메시지 관리
warnings.filterwarnings(action='ignore') # 경고 메시지 무시
import torch, gc # 메모리 관리 위해 PyTorch와 가비지 컬렉터 import

from torch.optim import lr_scheduler # 학습률 스케줄러

# !pip install efficientnet_pytorch
from efficientnet_pytorch import EfficientNet
# Out:
# Collecting efficientnet_pytorch
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from efficientnet_pytorch) (2.1.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->efficientnet_pytorch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->efficientnet_pytorch) (1.3.0)
# Building wheels for collected packages: efficientnet_pytorch
#   Building wheel for efficientnet_pytorch (setup.py) ... done
#   Created wheel for efficientnet_pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16428 sha256=c095cd235b8f77b7949de326de70cd456f322d29c1bb2dac17f429909687c50e
#   Stored in directory: /root/.cache/pip/wheels/03/3f/e9/911b1bc46869644912bda90a56bcf7b960f20b5187feea3baf
# Successfully built efficientnet_pytorch
# Installing collected packages: efficientnet_pytorch
# Successfully installed efficientnet_pytorch-0.7.1

# %%
# 디바이스 설정 (gpu 가능 시 cuda 장치, 안되면 cpu)
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
# 설정 (하이퍼파라미터 설정)
CFG = {
    'IMG_SIZE':224,
    'EPOCHS':30,
    'LEARNING_RATE':3e-4,
    'BATCH_SIZE':32,
    'SEED':41
}

# %%
def seed_everything(seed):
  random.seed(seed) # random 초기화해 시드값에 따라 같은 random 수 생성
  os.environ['PYTHONHASHSEED'] = str(seed) # 파이썬 해시 시드를 설정하여 해시 기반 작업의 일관성을 유지
  np.random.seed(seed) # numpy 초기화해 시드값에 따라 같은 random 수 생성
  torch.manual_seed(seed) # 파이토치의 random 초기화해 시드값에 따라 같은 random 수 생성
  torch.cuda.manual_seed(seed) # cuda(GPU)의 random 초기화해 시드값에 따라 같은 random 수 생성
  torch.backends.cudnn.deterministic = True # CuDNN 라이브러리의 동일한 연산을 보장
  torch.backends.cudnn.benchmark = True # CuDNN 연산 최적화 사용

# seed 고정
seed_everything(CFG['SEED'])

# %%
# %cd "/content/"
# !unzip "/content/drive/MyDrive/open.zip"
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: open/train/4097.jpg
#   inflating: __MACOSX/open/train/._4097.jpg
#   inflating: open/train/3920.jpg
#   inflating: __MACOSX/open/train/._3920.jpg
#   inflating: open/train/5389.jpg
#   inflating: __MACOSX/open/train/._5389.jpg
#   inflating: open/train/3908.jpg
#   inflating: __MACOSX/open/train/._3908.jpg
#   inflating: open/train/4901.jpg
#   inflating: __MACOSX/open/train/._4901.jpg
#   inflating: open/train/1879.jpg
#   inflating: __MACOSX/open/train/._1879.jpg
#   inflating: open/train/4915.jpg
#   inflating: __MACOSX/open/train/._4915.jpg
#   inflating: open/train/0352.jpg
#   inflating: __MACOSX/open/train/._0352.jpg
#   inflating: open/train/4134.jpg
#   inflating: __MACOSX/open/train/._4134.jpg
#   inflating: open/train/2545.jpg
#   inflating: __MACOSX/open/train/._2545.jpg
#   inflating: open/train/3883.jpg
#   inflating: __MACOSX/open/train/._3883.jpg
#   inflating: open/train/2223.jpg
#   inflating: __MACOSX/open/train/._2223.jpg
#   inflating: open/train/4652.jpg
#   inflating: __MACOSX/open/train/._4652.jpg
#   inflating: open/train/0434.jpg
#   inflating: __MACOSX/open/train/._0434.jpg
#   inflating: open/train/0420.jpg
#   inflating: __MACOSX/open/train/._0420.jpg
#   inflating: open/train/5558.jpg
#   inflating: __MACOSX/open/train/._5558.jpg
#   inflating: open/train/2237.jpg
#   inflating: __MACOSX/open/train/._2237.jpg
#   inflating: open/train/3129.jpg
#   inflating: __MACOSX/open/train/._3129.jpg
#   inflating: open/train/4646.jpg
#   inflating: __MACOSX/open/train/._4646.jpg
#   inflating: open/train/4120.jpg
#   inflating: __MACOSX/open/train/._4120.jpg
#   inflating: open/train/2551.jpg
#   inflating: __MACOSX/open/train/._2551.jpg
#   inflating: open/train/3897.jpg
#   inflating: __MACOSX/open/train/._3897.jpg
#   inflating: open/train/1058.jpg
#   inflating: __MACOSX/open/train/._1058.jpg
#   inflating: open/train/0346.jpg
#   inflating: __MACOSX/open/train/._0346.jpg
#   inflating: open/train/4108.jpg
#   inflating: __MACOSX/open/train/._4108.jpg
#   inflating: open/train/3667.jpg
#   inflating: __MACOSX/open/train/._3667.jpg
#   inflating: open/train/2579.jpg
#   inflating: __MACOSX/open/train/._2579.jpg
#   inflating: open/train/5216.jpg
#   inflating: __MACOSX/open/train/._5216.jpg
#   inflating: open/train/1070.jpg
#   inflating: __MACOSX/open/train/._1070.jpg
#   inflating: open/train/0408.jpg
#   inflating: __MACOSX/open/train/._0408.jpg
#   inflating: open/train/1716.jpg
#   inflating: __MACOSX/open/train/._1716.jpg
#   inflating: open/train/5570.jpg
#   inflating: __MACOSX/open/train/._5570.jpg
#   inflating: open/train/3101.jpg
#   inflating: __MACOSX/open/train/._3101.jpg
#   inflating: open/train/5564.jpg
#   inflating: __MACOSX/open/train/._5564.jpg
#   inflating: open/train/3115.jpg
#   inflating: __MACOSX/open/train/._3115.jpg
#   inflating: open/train/1702.jpg
#   inflating: __MACOSX/open/train/._1702.jpg
#   inflating: open/train/1064.jpg
#   inflating: __MACOSX/open/train/._1064.jpg
#   inflating: open/train/3673.jpg
#   inflating: __MACOSX/open/train/._3673.jpg
#   inflating: open/train/5202.jpg
#   inflating: __MACOSX/open/train/._5202.jpg
#   inflating: open/train/2586.jpg
#   inflating: __MACOSX/open/train/._2586.jpg
#   inflating: open/train/3840.jpg
#   inflating: __MACOSX/open/train/._3840.jpg
#   inflating: open/train/3698.jpg
#   inflating: __MACOSX/open/train/._3698.jpg
#   inflating: open/train/0391.jpg
#   inflating: __MACOSX/open/train/._0391.jpg
#   inflating: open/train/1931.jpg
#   inflating: __MACOSX/open/train/._1931.jpg
#   inflating: open/train/4691.jpg
#   inflating: __MACOSX/open/train/._4691.jpg
#   inflating: open/train/4849.jpg
#   inflating: __MACOSX/open/train/._4849.jpg
#   inflating: open/train/4685.jpg
#   inflating: __MACOSX/open/train/._4685.jpg
#   inflating: open/train/1925.jpg
#   inflating: __MACOSX/open/train/._1925.jpg
#   inflating: open/train/0385.jpg
#   inflating: __MACOSX/open/train/._0385.jpg
#   inflating: open/train/2592.jpg
#   inflating: __MACOSX/open/train/._2592.jpg
#   inflating: open/train/3854.jpg
#   inflating: __MACOSX/open/train/._3854.jpg
#   inflating: open/train/4875.jpg
#   inflating: __MACOSX/open/train/._4875.jpg
#   inflating: open/train/1919.jpg
#   inflating: __MACOSX/open/train/._1919.jpg
#   inflating: open/train/4861.jpg
#   inflating: __MACOSX/open/train/._4861.jpg
#   inflating: open/train/3868.jpg
#   inflating: __MACOSX/open/train/._3868.jpg
#   inflating: open/train/1528.jpg
#   inflating: __MACOSX/open/train/._1528.jpg
#   inflating: open/train/0636.jpg
#   inflating: __MACOSX/open/train/._0636.jpg
#   inflating: open/train/4450.jpg
#   inflating: __MACOSX/open/train/._4450.jpg
#   inflating: open/train/2021.jpg
#   inflating: __MACOSX/open/train/._2021.jpg
#   inflating: open/train/5028.jpg
#   inflating: __MACOSX/open/train/._5028.jpg
#   inflating: open/train/2747.jpg
#   inflating: __MACOSX/open/train/._2747.jpg
#   inflating: open/train/3459.jpg
#   inflating: __MACOSX/open/train/._3459.jpg
#   inflating: open/train/4336.jpg
#   inflating: __MACOSX/open/train/._4336.jpg
#   inflating: open/train/0150.jpg
#   inflating: __MACOSX/open/train/._0150.jpg
#   inflating: open/train/0144.jpg
#   inflating: __MACOSX/open/train/._0144.jpg
#   inflating: open/train/2753.jpg
#   inflating: __MACOSX/open/train/._2753.jpg
#   inflating: open/train/4322.jpg
#   inflating: __MACOSX/open/train/._4322.jpg
#   inflating: open/train/4444.jpg
#   inflating: __MACOSX/open/train/._4444.jpg
#   inflating: open/train/2035.jpg
#   inflating: __MACOSX/open/train/._2035.jpg
#   inflating: open/train/0622.jpg
#   inflating: __MACOSX/open/train/._0622.jpg
#   inflating: open/train/3303.jpg
#   inflating: __MACOSX/open/train/._3303.jpg
#   inflating: open/train/5772.jpg
#   inflating: __MACOSX/open/train/._5772.jpg
#   inflating: open/train/1514.jpg
#   inflating: __MACOSX/open/train/._1514.jpg
#   inflating: open/train/1272.jpg
#   inflating: __MACOSX/open/train/._1272.jpg
#   inflating: open/train/5014.jpg
#   inflating: __MACOSX/open/train/._5014.jpg
#   inflating: open/train/3465.jpg
#   inflating: __MACOSX/open/train/._3465.jpg
#   inflating: open/train/5000.jpg
#   inflating: __MACOSX/open/train/._5000.jpg
#   inflating: open/train/3471.jpg
#   inflating: __MACOSX/open/train/._3471.jpg
#   inflating: open/train/0178.jpg
#   inflating: __MACOSX/open/train/._0178.jpg
#   inflating: open/train/1266.jpg
#   inflating: __MACOSX/open/train/._1266.jpg
#   inflating: open/train/1500.jpg
#   inflating: __MACOSX/open/train/._1500.jpg
#   inflating: open/train/4478.jpg
#   inflating: __MACOSX/open/train/._4478.jpg
#   inflating: open/train/3317.jpg
#   inflating: __MACOSX/open/train/._3317.jpg
#   inflating: open/train/2009.jpg
#   inflating: __MACOSX/open/train/._2009.jpg
#   inflating: open/train/5766.jpg
#   inflating: __MACOSX/open/train/._5766.jpg
#   inflating: open/train/4493.jpg
#   inflating: __MACOSX/open/train/._4493.jpg
#   inflating: open/train/0193.jpg
#   inflating: __MACOSX/open/train/._0193.jpg
#   inflating: open/train/2784.jpg
#   inflating: __MACOSX/open/train/._2784.jpg
#   inflating: open/train/2948.jpg
#   inflating: __MACOSX/open/train/._2948.jpg
#   inflating: open/train/2790.jpg
#   inflating: __MACOSX/open/train/._2790.jpg
#   inflating: open/train/1299.jpg
#   inflating: __MACOSX/open/train/._1299.jpg
#   inflating: open/train/0187.jpg
#   inflating: __MACOSX/open/train/._0187.jpg
#   inflating: open/train/0839.jpg
#   inflating: __MACOSX/open/train/._0839.jpg
#   inflating: open/train/5799.jpg
#   inflating: __MACOSX/open/train/._5799.jpg
#   inflating: open/train/4487.jpg
#   inflating: __MACOSX/open/train/._4487.jpg
#   inflating: open/train/0811.jpg
#   inflating: __MACOSX/open/train/._0811.jpg
#   inflating: open/train/2960.jpg
#   inflating: __MACOSX/open/train/._2960.jpg
#   inflating: open/train/2974.jpg
#   inflating: __MACOSX/open/train/._2974.jpg
#   inflating: open/train/0805.jpg
#   inflating: __MACOSX/open/train/._0805.jpg
#   inflating: open/train/2975.jpg
#   inflating: __MACOSX/open/train/._2975.jpg
#   inflating: open/train/0804.jpg
#   inflating: __MACOSX/open/train/._0804.jpg
#   inflating: open/train/0810.jpg
#   inflating: __MACOSX/open/train/._0810.jpg
#   inflating: open/train/2961.jpg
#   inflating: __MACOSX/open/train/._2961.jpg
#   inflating: open/train/0186.jpg
#   inflating: __MACOSX/open/train/._0186.jpg
#   inflating: open/train/1298.jpg
#   inflating: __MACOSX/open/train/._1298.jpg
#   inflating: open/train/2791.jpg
#   inflating: __MACOSX/open/train/._2791.jpg
#   inflating: open/train/2949.jpg
#   inflating: __MACOSX/open/train/._2949.jpg
#   inflating: open/train/4486.jpg
#   inflating: __MACOSX/open/train/._4486.jpg
#   inflating: open/train/5798.jpg
#   inflating: __MACOSX/open/train/._5798.jpg
#   inflating: open/train/0838.jpg
#   inflating: __MACOSX/open/train/._0838.jpg
#   inflating: open/train/4492.jpg
#   inflating: __MACOSX/open/train/._4492.jpg
#   inflating: open/train/2785.jpg
#   inflating: __MACOSX/open/train/._2785.jpg
#   inflating: open/train/0192.jpg
#   inflating: __MACOSX/open/train/._0192.jpg
#   inflating: open/train/1267.jpg
#   inflating: __MACOSX/open/train/._1267.jpg
#   inflating: open/train/0179.jpg
#   inflating: __MACOSX/open/train/._0179.jpg
#   inflating: open/train/3470.jpg
#   inflating: __MACOSX/open/train/._3470.jpg
#   inflating: open/train/5001.jpg
#   inflating: __MACOSX/open/train/._5001.jpg
#   inflating: open/train/5767.jpg
#   inflating: __MACOSX/open/train/._5767.jpg
#   inflating: open/train/2008.jpg
#   inflating: __MACOSX/open/train/._2008.jpg
#   inflating: open/train/3316.jpg
#   inflating: __MACOSX/open/train/._3316.jpg
#   inflating: open/train/4479.jpg
#   inflating: __MACOSX/open/train/._4479.jpg
#   inflating: open/train/1501.jpg
#   inflating: __MACOSX/open/train/._1501.jpg
#   inflating: open/train/1515.jpg
#   inflating: __MACOSX/open/train/._1515.jpg
#   inflating: open/train/5773.jpg
#   inflating: __MACOSX/open/train/._5773.jpg
#   inflating: open/train/3302.jpg
#   inflating: __MACOSX/open/train/._3302.jpg
#   inflating: open/train/3464.jpg
#   inflating: __MACOSX/open/train/._3464.jpg
#   inflating: open/train/5015.jpg
#   inflating: __MACOSX/open/train/._5015.jpg
#   inflating: open/train/1273.jpg
#   inflating: __MACOSX/open/train/._1273.jpg
#   inflating: open/train/4323.jpg
#   inflating: __MACOSX/open/train/._4323.jpg
#   inflating: open/train/2752.jpg
#   inflating: __MACOSX/open/train/._2752.jpg
#   inflating: open/train/0145.jpg
#   inflating: __MACOSX/open/train/._0145.jpg
#   inflating: open/train/0623.jpg
#   inflating: __MACOSX/open/train/._0623.jpg
#   inflating: open/train/2034.jpg
#   inflating: __MACOSX/open/train/._2034.jpg
#   inflating: open/train/4445.jpg
#   inflating: __MACOSX/open/train/._4445.jpg
#   inflating: open/train/2020.jpg
#   inflating: __MACOSX/open/train/._2020.jpg
#   inflating: open/train/4451.jpg
#   inflating: __MACOSX/open/train/._4451.jpg
#   inflating: open/train/0637.jpg
#   inflating: __MACOSX/open/train/._0637.jpg
#   inflating: open/train/1529.jpg
#   inflating: __MACOSX/open/train/._1529.jpg
#   inflating: open/train/0151.jpg
#   inflating: __MACOSX/open/train/._0151.jpg
#   inflating: open/train/4337.jpg
#   inflating: __MACOSX/open/train/._4337.jpg
#   inflating: open/train/3458.jpg
#   inflating: __MACOSX/open/train/._3458.jpg
#   inflating: open/train/2746.jpg
#   inflating: __MACOSX/open/train/._2746.jpg
#   inflating: open/train/5029.jpg
#   inflating: __MACOSX/open/train/._5029.jpg
#   inflating: open/train/4860.jpg
#   inflating: __MACOSX/open/train/._4860.jpg
#   inflating: open/train/1918.jpg
#   inflating: __MACOSX/open/train/._1918.jpg
#   inflating: open/train/3869.jpg
#   inflating: __MACOSX/open/train/._3869.jpg
#   inflating: open/train/4874.jpg
#   inflating: __MACOSX/open/train/._4874.jpg
#   inflating: open/train/1924.jpg
#   inflating: __MACOSX/open/train/._1924.jpg
#   inflating: open/train/4684.jpg
#   inflating: __MACOSX/open/train/._4684.jpg
#   inflating: open/train/3855.jpg
#   inflating: __MACOSX/open/train/._3855.jpg
#   inflating: open/train/2593.jpg
#   inflating: __MACOSX/open/train/._2593.jpg
#   inflating: open/train/0384.jpg
#   inflating: __MACOSX/open/train/._0384.jpg
#   inflating: open/train/0390.jpg
#   inflating: __MACOSX/open/train/._0390.jpg
#   inflating: open/train/3699.jpg
#   inflating: __MACOSX/open/train/._3699.jpg
#   inflating: open/train/3841.jpg
#   inflating: __MACOSX/open/train/._3841.jpg
#   inflating: open/train/2587.jpg
#   inflating: __MACOSX/open/train/._2587.jpg
#   inflating: open/train/4848.jpg
#   inflating: __MACOSX/open/train/._4848.jpg
#   inflating: open/train/4690.jpg
#   inflating: __MACOSX/open/train/._4690.jpg
#   inflating: open/train/1930.jpg
#   inflating: __MACOSX/open/train/._1930.jpg
#   inflating: open/train/1703.jpg
#   inflating: __MACOSX/open/train/._1703.jpg
#   inflating: open/train/3114.jpg
#   inflating: __MACOSX/open/train/._3114.jpg
#   inflating: open/train/5565.jpg
#   inflating: __MACOSX/open/train/._5565.jpg
#   inflating: open/train/5203.jpg
#   inflating: __MACOSX/open/train/._5203.jpg
#   inflating: open/train/3672.jpg
#   inflating: __MACOSX/open/train/._3672.jpg
#   inflating: open/train/1065.jpg
#   inflating: __MACOSX/open/train/._1065.jpg
#   inflating: open/train/1071.jpg
#   inflating: __MACOSX/open/train/._1071.jpg
#   inflating: open/train/5217.jpg
#   inflating: __MACOSX/open/train/._5217.jpg
#   inflating: open/train/2578.jpg
#   inflating: __MACOSX/open/train/._2578.jpg
#   inflating: open/train/3666.jpg
#   inflating: __MACOSX/open/train/._3666.jpg
#   inflating: open/train/4109.jpg
#   inflating: __MACOSX/open/train/._4109.jpg
#   inflating: open/train/3100.jpg
#   inflating: __MACOSX/open/train/._3100.jpg
#   inflating: open/train/5571.jpg
#   inflating: __MACOSX/open/train/._5571.jpg
#   inflating: open/train/1717.jpg
#   inflating: __MACOSX/open/train/._1717.jpg
#   inflating: open/train/0409.jpg
#   inflating: __MACOSX/open/train/._0409.jpg
#   inflating: open/train/4647.jpg
#   inflating: __MACOSX/open/train/._4647.jpg
#   inflating: open/train/3128.jpg
#   inflating: __MACOSX/open/train/._3128.jpg
#   inflating: open/train/2236.jpg
#   inflating: __MACOSX/open/train/._2236.jpg
#   inflating: open/train/5559.jpg
#   inflating: __MACOSX/open/train/._5559.jpg
#   inflating: open/train/0421.jpg
#   inflating: __MACOSX/open/train/._0421.jpg
#   inflating: open/train/0347.jpg
#   inflating: __MACOSX/open/train/._0347.jpg
#   inflating: open/train/1059.jpg
#   inflating: __MACOSX/open/train/._1059.jpg
#   inflating: open/train/3896.jpg
#   inflating: __MACOSX/open/train/._3896.jpg
#   inflating: open/train/2550.jpg
#   inflating: __MACOSX/open/train/._2550.jpg
#   inflating: open/train/4121.jpg
#   inflating: __MACOSX/open/train/._4121.jpg
#   inflating: open/train/3882.jpg
#   inflating: __MACOSX/open/train/._3882.jpg
#   inflating: open/train/2544.jpg
#   inflating: __MACOSX/open/train/._2544.jpg
#   inflating: open/train/4135.jpg
#   inflating: __MACOSX/open/train/._4135.jpg
#   inflating: open/train/0353.jpg
#   inflating: __MACOSX/open/train/._0353.jpg
#   inflating: open/train/0435.jpg
#   inflating: __MACOSX/open/train/._0435.jpg
#   inflating: open/train/4653.jpg
#   inflating: __MACOSX/open/train/._4653.jpg
#   inflating: open/train/2222.jpg
#   inflating: __MACOSX/open/train/._2222.jpg
#   inflating: open/train/4914.jpg
#   inflating: __MACOSX/open/train/._4914.jpg
#   inflating: open/train/3909.jpg
#   inflating: __MACOSX/open/train/._3909.jpg
#   inflating: open/train/1878.jpg
#   inflating: __MACOSX/open/train/._1878.jpg
#   inflating: open/train/4900.jpg
#   inflating: __MACOSX/open/train/._4900.jpg
#   inflating: open/train/1688.jpg
#   inflating: __MACOSX/open/train/._1688.jpg
#   inflating: open/train/1850.jpg
#   inflating: __MACOSX/open/train/._1850.jpg
#   inflating: open/train/0596.jpg
#   inflating: __MACOSX/open/train/._0596.jpg
#   inflating: open/train/4928.jpg
#   inflating: __MACOSX/open/train/._4928.jpg
#   inflating: open/train/2381.jpg
#   inflating: __MACOSX/open/train/._2381.jpg
#   inflating: open/train/5388.jpg
#   inflating: __MACOSX/open/train/._5388.jpg
#   inflating: open/train/3921.jpg
#   inflating: __MACOSX/open/train/._3921.jpg
#   inflating: open/train/4096.jpg
#   inflating: __MACOSX/open/train/._4096.jpg
#   inflating: open/train/3935.jpg
#   inflating: __MACOSX/open/train/._3935.jpg
#   inflating: open/train/4082.jpg
#   inflating: __MACOSX/open/train/._4082.jpg
#   inflating: open/train/2395.jpg
#   inflating: __MACOSX/open/train/._2395.jpg
#   inflating: open/train/1844.jpg
#   inflating: __MACOSX/open/train/._1844.jpg
#   inflating: open/train/0582.jpg
#   inflating: __MACOSX/open/train/._0582.jpg
#   inflating: open/train/0569.jpg
#   inflating: __MACOSX/open/train/._0569.jpg
#   inflating: open/train/1677.jpg
#   inflating: __MACOSX/open/train/._1677.jpg
#   inflating: open/train/5411.jpg
#   inflating: __MACOSX/open/train/._5411.jpg
#   inflating: open/train/3060.jpg
#   inflating: __MACOSX/open/train/._3060.jpg
#   inflating: open/train/4069.jpg
#   inflating: __MACOSX/open/train/._4069.jpg
#   inflating: open/train/3706.jpg
#   inflating: __MACOSX/open/train/._3706.jpg
#   inflating: open/train/2418.jpg
#   inflating: __MACOSX/open/train/._2418.jpg
#   inflating: open/train/5377.jpg
#   inflating: __MACOSX/open/train/._5377.jpg
#   inflating: open/train/1111.jpg
#   inflating: __MACOSX/open/train/._1111.jpg
#   inflating: open/train/1105.jpg
#   inflating: __MACOSX/open/train/._1105.jpg
#   inflating: open/train/3712.jpg
#   inflating: __MACOSX/open/train/._3712.jpg
#   inflating: open/train/5363.jpg
#   inflating: __MACOSX/open/train/._5363.jpg
#   inflating: open/train/5405.jpg
#   inflating: __MACOSX/open/train/._5405.jpg
#   inflating: open/train/3074.jpg
#   inflating: __MACOSX/open/train/._3074.jpg
#   inflating: open/train/1663.jpg
#   inflating: __MACOSX/open/train/._1663.jpg
#   inflating: open/train/2342.jpg
#   inflating: __MACOSX/open/train/._2342.jpg
#   inflating: open/train/4733.jpg
#   inflating: __MACOSX/open/train/._4733.jpg
#   inflating: open/train/1893.jpg
#   inflating: __MACOSX/open/train/._1893.jpg
#   inflating: open/train/0555.jpg
#   inflating: __MACOSX/open/train/._0555.jpg
#   inflating: open/train/0233.jpg
#   inflating: __MACOSX/open/train/._0233.jpg
#   inflating: open/train/4055.jpg
#   inflating: __MACOSX/open/train/._4055.jpg
#   inflating: open/train/2424.jpg
#   inflating: __MACOSX/open/train/._2424.jpg
#   inflating: open/train/4041.jpg
#   inflating: __MACOSX/open/train/._4041.jpg
#   inflating: open/train/2430.jpg
#   inflating: __MACOSX/open/train/._2430.jpg
#   inflating: open/train/1139.jpg
#   inflating: __MACOSX/open/train/._1139.jpg
#   inflating: open/train/0227.jpg
#   inflating: __MACOSX/open/train/._0227.jpg
#   inflating: open/train/1887.jpg
#   inflating: __MACOSX/open/train/._1887.jpg
#   inflating: open/train/0541.jpg
#   inflating: __MACOSX/open/train/._0541.jpg
#   inflating: open/train/5439.jpg
#   inflating: __MACOSX/open/train/._5439.jpg
#   inflating: open/train/2356.jpg
#   inflating: __MACOSX/open/train/._2356.jpg
#   inflating: open/train/3048.jpg
#   inflating: __MACOSX/open/train/._3048.jpg
#   inflating: open/train/4727.jpg
#   inflating: __MACOSX/open/train/._4727.jpg
#   inflating: open/train/2801.jpg
#   inflating: __MACOSX/open/train/._2801.jpg
#   inflating: open/train/0970.jpg
#   inflating: __MACOSX/open/train/._0970.jpg
#   inflating: open/train/5808.jpg
#   inflating: __MACOSX/open/train/._5808.jpg
#   inflating: open/train/0964.jpg
#   inflating: __MACOSX/open/train/._0964.jpg
#   inflating: open/train/2815.jpg
#   inflating: __MACOSX/open/train/._2815.jpg
#   inflating: open/train/4294.jpg
#   inflating: __MACOSX/open/train/._4294.jpg
#   inflating: open/train/2183.jpg
#   inflating: __MACOSX/open/train/._2183.jpg
#   inflating: open/train/5834.jpg
#   inflating: __MACOSX/open/train/._5834.jpg
#   inflating: open/train/0794.jpg
#   inflating: __MACOSX/open/train/._0794.jpg
#   inflating: open/train/0780.jpg
#   inflating: __MACOSX/open/train/._0780.jpg
#   inflating: open/train/0958.jpg
#   inflating: __MACOSX/open/train/._0958.jpg
#   inflating: open/train/2197.jpg
#   inflating: __MACOSX/open/train/._2197.jpg
#   inflating: open/train/3289.jpg
#   inflating: __MACOSX/open/train/._3289.jpg
#   inflating: open/train/5820.jpg
#   inflating: __MACOSX/open/train/._5820.jpg
#   inflating: open/train/2829.jpg
#   inflating: __MACOSX/open/train/._2829.jpg
#   inflating: open/train/4280.jpg
#   inflating: __MACOSX/open/train/._4280.jpg
#   inflating: open/train/1313.jpg
#   inflating: __MACOSX/open/train/._1313.jpg
#   inflating: open/train/5175.jpg
#   inflating: __MACOSX/open/train/._5175.jpg
#   inflating: open/train/3504.jpg
#   inflating: __MACOSX/open/train/._3504.jpg
#   inflating: open/train/3262.jpg
#   inflating: __MACOSX/open/train/._3262.jpg
#   inflating: open/train/5613.jpg
#   inflating: __MACOSX/open/train/._5613.jpg
#   inflating: open/train/1475.jpg
#   inflating: __MACOSX/open/train/._1475.jpg
#   inflating: open/train/1461.jpg
#   inflating: __MACOSX/open/train/._1461.jpg
#   inflating: open/train/4519.jpg
#   inflating: __MACOSX/open/train/._4519.jpg
#   inflating: open/train/3276.jpg
#   inflating: __MACOSX/open/train/._3276.jpg
#   inflating: open/train/2168.jpg
#   inflating: __MACOSX/open/train/._2168.jpg
#   inflating: open/train/5607.jpg
#   inflating: __MACOSX/open/train/._5607.jpg
#   inflating: open/train/5161.jpg
#   inflating: __MACOSX/open/train/._5161.jpg
#   inflating: open/train/3510.jpg
#   inflating: __MACOSX/open/train/._3510.jpg
#   inflating: open/train/0019.jpg
#   inflating: __MACOSX/open/train/._0019.jpg
#   inflating: open/train/1307.jpg
#   inflating: __MACOSX/open/train/._1307.jpg
#   inflating: open/train/5149.jpg
#   inflating: __MACOSX/open/train/._5149.jpg
#   inflating: open/train/2626.jpg
#   inflating: __MACOSX/open/train/._2626.jpg
#   inflating: open/train/3538.jpg
#   inflating: __MACOSX/open/train/._3538.jpg
#   inflating: open/train/4257.jpg
#   inflating: __MACOSX/open/train/._4257.jpg
#   inflating: open/train/0031.jpg
#   inflating: __MACOSX/open/train/._0031.jpg
#   inflating: open/train/1449.jpg
#   inflating: __MACOSX/open/train/._1449.jpg
#   inflating: open/train/0757.jpg
#   inflating: __MACOSX/open/train/._0757.jpg
#   inflating: open/train/4531.jpg
#   inflating: __MACOSX/open/train/._4531.jpg
#   inflating: open/train/2140.jpg
#   inflating: __MACOSX/open/train/._2140.jpg
#   inflating: open/train/4525.jpg
#   inflating: __MACOSX/open/train/._4525.jpg
#   inflating: open/train/2154.jpg
#   inflating: __MACOSX/open/train/._2154.jpg
#   inflating: open/train/0743.jpg
#   inflating: __MACOSX/open/train/._0743.jpg
#   inflating: open/train/0025.jpg
#   inflating: __MACOSX/open/train/._0025.jpg
#   inflating: open/train/2632.jpg
#   inflating: __MACOSX/open/train/._2632.jpg
#   inflating: open/train/4243.jpg
#   inflating: __MACOSX/open/train/._4243.jpg
#   inflating: open/train/1303.jpg
#   inflating: __MACOSX/open/train/._1303.jpg
#   inflating: open/train/3514.jpg
#   inflating: __MACOSX/open/train/._3514.jpg
#   inflating: open/train/5165.jpg
#   inflating: __MACOSX/open/train/._5165.jpg
#   inflating: open/train/5603.jpg
#   inflating: __MACOSX/open/train/._5603.jpg
#   inflating: open/train/3272.jpg
#   inflating: __MACOSX/open/train/._3272.jpg
#   inflating: open/train/1465.jpg
#   inflating: __MACOSX/open/train/._1465.jpg
#   inflating: open/train/1471.jpg
#   inflating: __MACOSX/open/train/._1471.jpg
#   inflating: open/train/2178.jpg
#   inflating: __MACOSX/open/train/._2178.jpg
#   inflating: open/train/5617.jpg
#   inflating: __MACOSX/open/train/._5617.jpg
#   inflating: open/train/4509.jpg
#   inflating: __MACOSX/open/train/._4509.jpg
#   inflating: open/train/3266.jpg
#   inflating: __MACOSX/open/train/._3266.jpg
#   inflating: open/train/3500.jpg
#   inflating: __MACOSX/open/train/._3500.jpg
#   inflating: open/train/5171.jpg
#   inflating: __MACOSX/open/train/._5171.jpg
#   inflating: open/train/1317.jpg
#   inflating: __MACOSX/open/train/._1317.jpg
#   inflating: open/train/0009.jpg
#   inflating: __MACOSX/open/train/._0009.jpg
#   inflating: open/train/3528.jpg
#   inflating: __MACOSX/open/train/._3528.jpg
#   inflating: open/train/4247.jpg
#   inflating: __MACOSX/open/train/._4247.jpg
#   inflating: open/train/5159.jpg
#   inflating: __MACOSX/open/train/._5159.jpg
#   inflating: open/train/2636.jpg
#   inflating: __MACOSX/open/train/._2636.jpg
#   inflating: open/train/0021.jpg
#   inflating: __MACOSX/open/train/._0021.jpg
#   inflating: open/train/0747.jpg
#   inflating: __MACOSX/open/train/._0747.jpg
#   inflating: open/train/1459.jpg
#   inflating: __MACOSX/open/train/._1459.jpg
#   inflating: open/train/2150.jpg
#   inflating: __MACOSX/open/train/._2150.jpg
#   inflating: open/train/4521.jpg
#   inflating: __MACOSX/open/train/._4521.jpg
#   inflating: open/train/2144.jpg
#   inflating: __MACOSX/open/train/._2144.jpg
#   inflating: open/train/4535.jpg
#   inflating: __MACOSX/open/train/._4535.jpg
#   inflating: open/train/0753.jpg
#   inflating: __MACOSX/open/train/._0753.jpg
#   inflating: open/train/0035.jpg
#   inflating: __MACOSX/open/train/._0035.jpg
#   inflating: open/train/4253.jpg
#   inflating: __MACOSX/open/train/._4253.jpg
#   inflating: open/train/2622.jpg
#   inflating: __MACOSX/open/train/._2622.jpg
#   inflating: open/train/2811.jpg
#   inflating: __MACOSX/open/train/._2811.jpg
#   inflating: open/train/0960.jpg
#   inflating: __MACOSX/open/train/._0960.jpg
#   inflating: open/train/5818.jpg
#   inflating: __MACOSX/open/train/._5818.jpg
#   inflating: open/train/0974.jpg
#   inflating: __MACOSX/open/train/._0974.jpg
#   inflating: open/train/2805.jpg
#   inflating: __MACOSX/open/train/._2805.jpg
#   inflating: open/train/4284.jpg
#   inflating: __MACOSX/open/train/._4284.jpg
#   inflating: open/train/5824.jpg
#   inflating: __MACOSX/open/train/._5824.jpg
#   inflating: open/train/2193.jpg
#   inflating: __MACOSX/open/train/._2193.jpg
#   inflating: open/train/0784.jpg
#   inflating: __MACOSX/open/train/._0784.jpg
#   inflating: open/train/0948.jpg
#   inflating: __MACOSX/open/train/._0948.jpg
#   inflating: open/train/0790.jpg
#   inflating: __MACOSX/open/train/._0790.jpg
#   inflating: open/train/5830.jpg
#   inflating: __MACOSX/open/train/._5830.jpg
#   inflating: open/train/3299.jpg
#   inflating: __MACOSX/open/train/._3299.jpg
#   inflating: open/train/2187.jpg
#   inflating: __MACOSX/open/train/._2187.jpg
#   inflating: open/train/4290.jpg
#   inflating: __MACOSX/open/train/._4290.jpg
#   inflating: open/train/2839.jpg
#   inflating: __MACOSX/open/train/._2839.jpg
#   inflating: open/train/1667.jpg
#   inflating: __MACOSX/open/train/._1667.jpg
#   inflating: open/train/0579.jpg
#   inflating: __MACOSX/open/train/._0579.jpg
#   inflating: open/train/3070.jpg
#   inflating: __MACOSX/open/train/._3070.jpg
#   inflating: open/train/5401.jpg
#   inflating: __MACOSX/open/train/._5401.jpg
#   inflating: open/train/2408.jpg
#   inflating: __MACOSX/open/train/._2408.jpg
#   inflating: open/train/5367.jpg
#   inflating: __MACOSX/open/train/._5367.jpg
#   inflating: open/train/4079.jpg
#   inflating: __MACOSX/open/train/._4079.jpg
#   inflating: open/train/3716.jpg
#   inflating: __MACOSX/open/train/._3716.jpg
#   inflating: open/train/1101.jpg
#   inflating: __MACOSX/open/train/._1101.jpg
#   inflating: open/train/1115.jpg
#   inflating: __MACOSX/open/train/._1115.jpg
#   inflating: open/train/5373.jpg
#   inflating: __MACOSX/open/train/._5373.jpg
#   inflating: open/train/3702.jpg
#   inflating: __MACOSX/open/train/._3702.jpg
#   inflating: open/train/3064.jpg
#   inflating: __MACOSX/open/train/._3064.jpg
#   inflating: open/train/5415.jpg
#   inflating: __MACOSX/open/train/._5415.jpg
#   inflating: open/train/1673.jpg
#   inflating: __MACOSX/open/train/._1673.jpg
#   inflating: open/train/4723.jpg
#   inflating: __MACOSX/open/train/._4723.jpg
#   inflating: open/train/2352.jpg
#   inflating: __MACOSX/open/train/._2352.jpg
#   inflating: open/train/1883.jpg
#   inflating: __MACOSX/open/train/._1883.jpg
#   inflating: open/train/0545.jpg
#   inflating: __MACOSX/open/train/._0545.jpg
#   inflating: open/train/0223.jpg
#   inflating: __MACOSX/open/train/._0223.jpg
#   inflating: open/train/2434.jpg
#   inflating: __MACOSX/open/train/._2434.jpg
#   inflating: open/train/4045.jpg
#   inflating: __MACOSX/open/train/._4045.jpg
#   inflating: open/train/2420.jpg
#   inflating: __MACOSX/open/train/._2420.jpg
#   inflating: open/train/4051.jpg
#   inflating: __MACOSX/open/train/._4051.jpg
#   inflating: open/train/0237.jpg
#   inflating: __MACOSX/open/train/._0237.jpg
#   inflating: open/train/1129.jpg
#   inflating: __MACOSX/open/train/._1129.jpg
#   inflating: open/train/1897.jpg
#   inflating: __MACOSX/open/train/._1897.jpg
#   inflating: open/train/0551.jpg
#   inflating: __MACOSX/open/train/._0551.jpg
#   inflating: open/train/3058.jpg
#   inflating: __MACOSX/open/train/._3058.jpg
#   inflating: open/train/4737.jpg
#   inflating: __MACOSX/open/train/._4737.jpg
#   inflating: open/train/5429.jpg
#   inflating: __MACOSX/open/train/._5429.jpg
#   inflating: open/train/2346.jpg
#   inflating: __MACOSX/open/train/._2346.jpg
#   inflating: open/train/4904.jpg
#   inflating: __MACOSX/open/train/._4904.jpg
#   inflating: open/train/3919.jpg
#   inflating: __MACOSX/open/train/._3919.jpg
#   inflating: open/train/1868.jpg
#   inflating: __MACOSX/open/train/._1868.jpg
#   inflating: open/train/4910.jpg
#   inflating: __MACOSX/open/train/._4910.jpg
#   inflating: open/train/1840.jpg
#   inflating: __MACOSX/open/train/._1840.jpg
#   inflating: open/train/0586.jpg
#   inflating: __MACOSX/open/train/._0586.jpg
#   inflating: open/train/1698.jpg
#   inflating: __MACOSX/open/train/._1698.jpg
#   inflating: open/train/2391.jpg
#   inflating: __MACOSX/open/train/._2391.jpg
#   inflating: open/train/4938.jpg
#   inflating: __MACOSX/open/train/._4938.jpg
#   inflating: open/train/4086.jpg
#   inflating: __MACOSX/open/train/._4086.jpg
#   inflating: open/train/3931.jpg
#   inflating: __MACOSX/open/train/._3931.jpg
#   inflating: open/train/5398.jpg
#   inflating: __MACOSX/open/train/._5398.jpg
#   inflating: open/train/4092.jpg
#   inflating: __MACOSX/open/train/._4092.jpg
#   inflating: open/train/3925.jpg
#   inflating: __MACOSX/open/train/._3925.jpg
#   inflating: open/train/2385.jpg
#   inflating: __MACOSX/open/train/._2385.jpg
#   inflating: open/train/1854.jpg
#   inflating: __MACOSX/open/train/._1854.jpg
#   inflating: open/train/0592.jpg
#   inflating: __MACOSX/open/train/._0592.jpg
#   inflating: open/train/1713.jpg
#   inflating: __MACOSX/open/train/._1713.jpg
#   inflating: open/train/5575.jpg
#   inflating: __MACOSX/open/train/._5575.jpg
#   inflating: open/train/3104.jpg
#   inflating: __MACOSX/open/train/._3104.jpg
#   inflating: open/train/3662.jpg
#   inflating: __MACOSX/open/train/._3662.jpg
#   inflating: open/train/5213.jpg
#   inflating: __MACOSX/open/train/._5213.jpg
#   inflating: open/train/1075.jpg
#   inflating: __MACOSX/open/train/._1075.jpg
#   inflating: open/train/1061.jpg
#   inflating: __MACOSX/open/train/._1061.jpg
#   inflating: open/train/3676.jpg
#   inflating: __MACOSX/open/train/._3676.jpg
#   inflating: open/train/4119.jpg
#   inflating: __MACOSX/open/train/._4119.jpg
#   inflating: open/train/5207.jpg
#   inflating: __MACOSX/open/train/._5207.jpg
#   inflating: open/train/2568.jpg
#   inflating: __MACOSX/open/train/._2568.jpg
#   inflating: open/train/5561.jpg
#   inflating: __MACOSX/open/train/._5561.jpg
#   inflating: open/train/3110.jpg
#   inflating: __MACOSX/open/train/._3110.jpg
#   inflating: open/train/0419.jpg
#   inflating: __MACOSX/open/train/._0419.jpg
#   inflating: open/train/1707.jpg
#   inflating: __MACOSX/open/train/._1707.jpg
#   inflating: open/train/2226.jpg
#   inflating: __MACOSX/open/train/._2226.jpg
#   inflating: open/train/5549.jpg
#   inflating: __MACOSX/open/train/._5549.jpg
#   inflating: open/train/4657.jpg
#   inflating: __MACOSX/open/train/._4657.jpg
#   inflating: open/train/3138.jpg
#   inflating: __MACOSX/open/train/._3138.jpg
#   inflating: open/train/0431.jpg
#   inflating: __MACOSX/open/train/._0431.jpg
#   inflating: open/train/1049.jpg
#   inflating: __MACOSX/open/train/._1049.jpg
#   inflating: open/train/0357.jpg
#   inflating: __MACOSX/open/train/._0357.jpg
#   inflating: open/train/4131.jpg
#   inflating: __MACOSX/open/train/._4131.jpg
#   inflating: open/train/3886.jpg
#   inflating: __MACOSX/open/train/._3886.jpg
#   inflating: open/train/2540.jpg
#   inflating: __MACOSX/open/train/._2540.jpg
#   inflating: open/train/4125.jpg
#   inflating: __MACOSX/open/train/._4125.jpg
#   inflating: open/train/3892.jpg
#   inflating: __MACOSX/open/train/._3892.jpg
#   inflating: open/train/2554.jpg
#   inflating: __MACOSX/open/train/._2554.jpg
#   inflating: open/train/0343.jpg
#   inflating: __MACOSX/open/train/._0343.jpg
#   inflating: open/train/0425.jpg
#   inflating: __MACOSX/open/train/._0425.jpg
#   inflating: open/train/2232.jpg
#   inflating: __MACOSX/open/train/._2232.jpg
#   inflating: open/train/4643.jpg
#   inflating: __MACOSX/open/train/._4643.jpg
#   inflating: open/train/4870.jpg
#   inflating: __MACOSX/open/train/._4870.jpg
#   inflating: open/train/1908.jpg
#   inflating: __MACOSX/open/train/._1908.jpg
#   inflating: open/train/3879.jpg
#   inflating: __MACOSX/open/train/._3879.jpg
#   inflating: open/train/4864.jpg
#   inflating: __MACOSX/open/train/._4864.jpg
#   inflating: open/train/1934.jpg
#   inflating: __MACOSX/open/train/._1934.jpg
#   inflating: open/train/4694.jpg
#   inflating: __MACOSX/open/train/._4694.jpg
#   inflating: open/train/3845.jpg
#   inflating: __MACOSX/open/train/._3845.jpg
#   inflating: open/train/2583.jpg
#   inflating: __MACOSX/open/train/._2583.jpg
#   inflating: open/train/0394.jpg
#   inflating: __MACOSX/open/train/._0394.jpg
#   inflating: open/train/0380.jpg
#   inflating: __MACOSX/open/train/._0380.jpg
#   inflating: open/train/3851.jpg
#   inflating: __MACOSX/open/train/._3851.jpg
#   inflating: open/train/2597.jpg
#   inflating: __MACOSX/open/train/._2597.jpg
#   inflating: open/train/3689.jpg
#   inflating: __MACOSX/open/train/._3689.jpg
#   inflating: open/train/4680.jpg
#   inflating: __MACOSX/open/train/._4680.jpg
#   inflating: open/train/4858.jpg
#   inflating: __MACOSX/open/train/._4858.jpg
#   inflating: open/train/1920.jpg
#   inflating: __MACOSX/open/train/._1920.jpg
#   inflating: open/train/0169.jpg
#   inflating: __MACOSX/open/train/._0169.jpg
#   inflating: open/train/1277.jpg
#   inflating: __MACOSX/open/train/._1277.jpg
#   inflating: open/train/5011.jpg
#   inflating: __MACOSX/open/train/._5011.jpg
#   inflating: open/train/3460.jpg
#   inflating: __MACOSX/open/train/._3460.jpg
#   inflating: open/train/3306.jpg
#   inflating: __MACOSX/open/train/._3306.jpg
#   inflating: open/train/4469.jpg
#   inflating: __MACOSX/open/train/._4469.jpg
#   inflating: open/train/5777.jpg
#   inflating: __MACOSX/open/train/._5777.jpg
#   inflating: open/train/2018.jpg
#   inflating: __MACOSX/open/train/._2018.jpg
#   inflating: open/train/1511.jpg
#   inflating: __MACOSX/open/train/._1511.jpg
#   inflating: open/train/1505.jpg
#   inflating: __MACOSX/open/train/._1505.jpg
#   inflating: open/train/3312.jpg
#   inflating: __MACOSX/open/train/._3312.jpg
#   inflating: open/train/5763.jpg
#   inflating: __MACOSX/open/train/._5763.jpg
#   inflating: open/train/5005.jpg
#   inflating: __MACOSX/open/train/._5005.jpg
#   inflating: open/train/3474.jpg
#   inflating: __MACOSX/open/train/._3474.jpg
#   inflating: open/train/1263.jpg
#   inflating: __MACOSX/open/train/._1263.jpg
#   inflating: open/train/2742.jpg
#   inflating: __MACOSX/open/train/._2742.jpg
#   inflating: open/train/4333.jpg
#   inflating: __MACOSX/open/train/._4333.jpg
#   inflating: open/train/0155.jpg
#   inflating: __MACOSX/open/train/._0155.jpg
#   inflating: open/train/0633.jpg
#   inflating: __MACOSX/open/train/._0633.jpg
#   inflating: open/train/4455.jpg
#   inflating: __MACOSX/open/train/._4455.jpg
#   inflating: open/train/2024.jpg
#   inflating: __MACOSX/open/train/._2024.jpg
#   inflating: open/train/4441.jpg
#   inflating: __MACOSX/open/train/._4441.jpg
#   inflating: open/train/2030.jpg
#   inflating: __MACOSX/open/train/._2030.jpg
#   inflating: open/train/1539.jpg
#   inflating: __MACOSX/open/train/._1539.jpg
#   inflating: open/train/0627.jpg
#   inflating: __MACOSX/open/train/._0627.jpg
#   inflating: open/train/0141.jpg
#   inflating: __MACOSX/open/train/._0141.jpg
#   inflating: open/train/2756.jpg
#   inflating: __MACOSX/open/train/._2756.jpg
#   inflating: open/train/5039.jpg
#   inflating: __MACOSX/open/train/._5039.jpg
#   inflating: open/train/4327.jpg
#   inflating: __MACOSX/open/train/._4327.jpg
#   inflating: open/train/3448.jpg
#   inflating: __MACOSX/open/train/._3448.jpg
#   inflating: open/train/2965.jpg
#   inflating: __MACOSX/open/train/._2965.jpg
#   inflating: open/train/0814.jpg
#   inflating: __MACOSX/open/train/._0814.jpg
#   inflating: open/train/0800.jpg
#   inflating: __MACOSX/open/train/._0800.jpg
#   inflating: open/train/2971.jpg
#   inflating: __MACOSX/open/train/._2971.jpg
#   inflating: open/train/1288.jpg
#   inflating: __MACOSX/open/train/._1288.jpg
#   inflating: open/train/0196.jpg
#   inflating: __MACOSX/open/train/._0196.jpg
#   inflating: open/train/2959.jpg
#   inflating: __MACOSX/open/train/._2959.jpg
#   inflating: open/train/2781.jpg
#   inflating: __MACOSX/open/train/._2781.jpg
#   inflating: open/train/5788.jpg
#   inflating: __MACOSX/open/train/._5788.jpg
#   inflating: open/train/4496.jpg
#   inflating: __MACOSX/open/train/._4496.jpg
#   inflating: open/train/0828.jpg
#   inflating: __MACOSX/open/train/._0828.jpg
#   inflating: open/train/4482.jpg
#   inflating: __MACOSX/open/train/._4482.jpg
#   inflating: open/train/2795.jpg
#   inflating: __MACOSX/open/train/._2795.jpg
#   inflating: open/train/0182.jpg
#   inflating: __MACOSX/open/train/._0182.jpg
#   inflating: open/train/4483.jpg
#   inflating: __MACOSX/open/train/._4483.jpg
#   inflating: open/train/0183.jpg
#   inflating: __MACOSX/open/train/._0183.jpg
#   inflating: open/train/2794.jpg
#   inflating: __MACOSX/open/train/._2794.jpg
#   inflating: open/train/2780.jpg
#   inflating: __MACOSX/open/train/._2780.jpg
#   inflating: open/train/2958.jpg
#   inflating: __MACOSX/open/train/._2958.jpg
#   inflating: open/train/0197.jpg
#   inflating: __MACOSX/open/train/._0197.jpg
#   inflating: open/train/1289.jpg
#   inflating: __MACOSX/open/train/._1289.jpg
#   inflating: open/train/0829.jpg
#   inflating: __MACOSX/open/train/._0829.jpg
#   inflating: open/train/4497.jpg
#   inflating: __MACOSX/open/train/._4497.jpg
#   inflating: open/train/5789.jpg
#   inflating: __MACOSX/open/train/._5789.jpg
#   inflating: open/train/0801.jpg
#   inflating: __MACOSX/open/train/._0801.jpg
#   inflating: open/train/2970.jpg
#   inflating: __MACOSX/open/train/._2970.jpg
#   inflating: open/train/2964.jpg
#   inflating: __MACOSX/open/train/._2964.jpg
#   inflating: open/train/0815.jpg
#   inflating: __MACOSX/open/train/._0815.jpg
#   inflating: open/train/0626.jpg
#   inflating: __MACOSX/open/train/._0626.jpg
#   inflating: open/train/1538.jpg
#   inflating: __MACOSX/open/train/._1538.jpg
#   inflating: open/train/2031.jpg
#   inflating: __MACOSX/open/train/._2031.jpg
#   inflating: open/train/4440.jpg
#   inflating: __MACOSX/open/train/._4440.jpg
#   inflating: open/train/3449.jpg
#   inflating: __MACOSX/open/train/._3449.jpg
#   inflating: open/train/4326.jpg
#   inflating: __MACOSX/open/train/._4326.jpg
#   inflating: open/train/5038.jpg
#   inflating: __MACOSX/open/train/._5038.jpg
#   inflating: open/train/2757.jpg
#   inflating: __MACOSX/open/train/._2757.jpg
#   inflating: open/train/0140.jpg
#   inflating: __MACOSX/open/train/._0140.jpg
#   inflating: open/train/0154.jpg
#   inflating: __MACOSX/open/train/._0154.jpg
#   inflating: open/train/4332.jpg
#   inflating: __MACOSX/open/train/._4332.jpg
#   inflating: open/train/2743.jpg
#   inflating: __MACOSX/open/train/._2743.jpg
#   inflating: open/train/2025.jpg
#   inflating: __MACOSX/open/train/._2025.jpg
#   inflating: open/train/4454.jpg
#   inflating: __MACOSX/open/train/._4454.jpg
#   inflating: open/train/0632.jpg
#   inflating: __MACOSX/open/train/._0632.jpg
#   inflating: open/train/5762.jpg
#   inflating: __MACOSX/open/train/._5762.jpg
#   inflating: open/train/3313.jpg
#   inflating: __MACOSX/open/train/._3313.jpg
#   inflating: open/train/1504.jpg
#   inflating: __MACOSX/open/train/._1504.jpg
#   inflating: open/train/1262.jpg
#   inflating: __MACOSX/open/train/._1262.jpg
#   inflating: open/train/3475.jpg
#   inflating: __MACOSX/open/train/._3475.jpg
#   inflating: open/train/5004.jpg
#   inflating: __MACOSX/open/train/._5004.jpg
#   inflating: open/train/3461.jpg
#   inflating: __MACOSX/open/train/._3461.jpg
#   inflating: open/train/5010.jpg
#   inflating: __MACOSX/open/train/._5010.jpg
#   inflating: open/train/1276.jpg
#   inflating: __MACOSX/open/train/._1276.jpg
#   inflating: open/train/0168.jpg
#   inflating: __MACOSX/open/train/._0168.jpg
#   inflating: open/train/1510.jpg
#   inflating: __MACOSX/open/train/._1510.jpg
#   inflating: open/train/2019.jpg
#   inflating: __MACOSX/open/train/._2019.jpg
#   inflating: open/train/5776.jpg
#   inflating: __MACOSX/open/train/._5776.jpg
#   inflating: open/train/4468.jpg
#   inflating: __MACOSX/open/train/._4468.jpg
#   inflating: open/train/3307.jpg
#   inflating: __MACOSX/open/train/._3307.jpg
#   inflating: open/train/3688.jpg
#   inflating: __MACOSX/open/train/._3688.jpg
#   inflating: open/train/2596.jpg
#   inflating: __MACOSX/open/train/._2596.jpg
#   inflating: open/train/3850.jpg
#   inflating: __MACOSX/open/train/._3850.jpg
#   inflating: open/train/0381.jpg
#   inflating: __MACOSX/open/train/._0381.jpg
#   inflating: open/train/1921.jpg
#   inflating: __MACOSX/open/train/._1921.jpg
#   inflating: open/train/4859.jpg
#   inflating: __MACOSX/open/train/._4859.jpg
#   inflating: open/train/4681.jpg
#   inflating: __MACOSX/open/train/._4681.jpg
#   inflating: open/train/4695.jpg
#   inflating: __MACOSX/open/train/._4695.jpg
#   inflating: open/train/1935.jpg
#   inflating: __MACOSX/open/train/._1935.jpg
#   inflating: open/train/0395.jpg
#   inflating: __MACOSX/open/train/._0395.jpg
#   inflating: open/train/2582.jpg
#   inflating: __MACOSX/open/train/._2582.jpg
#   inflating: open/train/3844.jpg
#   inflating: __MACOSX/open/train/._3844.jpg
#   inflating: open/train/4865.jpg
#   inflating: __MACOSX/open/train/._4865.jpg
#   inflating: open/train/1909.jpg
#   inflating: __MACOSX/open/train/._1909.jpg
#   inflating: open/train/4871.jpg
#   inflating: __MACOSX/open/train/._4871.jpg
#   inflating: open/train/3878.jpg
#   inflating: __MACOSX/open/train/._3878.jpg
#   inflating: open/train/0342.jpg
#   inflating: __MACOSX/open/train/._0342.jpg
#   inflating: open/train/2555.jpg
#   inflating: __MACOSX/open/train/._2555.jpg
#   inflating: open/train/3893.jpg
#   inflating: __MACOSX/open/train/._3893.jpg
#   inflating: open/train/4124.jpg
#   inflating: __MACOSX/open/train/._4124.jpg
#   inflating: open/train/4642.jpg
#   inflating: __MACOSX/open/train/._4642.jpg
#   inflating: open/train/2233.jpg
#   inflating: __MACOSX/open/train/._2233.jpg
#   inflating: open/train/0424.jpg
#   inflating: __MACOSX/open/train/._0424.jpg
#   inflating: open/train/0430.jpg
#   inflating: __MACOSX/open/train/._0430.jpg
#   inflating: open/train/3139.jpg
#   inflating: __MACOSX/open/train/._3139.jpg
#   inflating: open/train/4656.jpg
#   inflating: __MACOSX/open/train/._4656.jpg
#   inflating: open/train/5548.jpg
#   inflating: __MACOSX/open/train/._5548.jpg
#   inflating: open/train/2227.jpg
#   inflating: __MACOSX/open/train/._2227.jpg
#   inflating: open/train/2541.jpg
#   inflating: __MACOSX/open/train/._2541.jpg
#   inflating: open/train/3887.jpg
#   inflating: __MACOSX/open/train/._3887.jpg
#   inflating: open/train/4130.jpg
#   inflating: __MACOSX/open/train/._4130.jpg
#   inflating: open/train/0356.jpg
#   inflating: __MACOSX/open/train/._0356.jpg
#   inflating: open/train/1048.jpg
#   inflating: __MACOSX/open/train/._1048.jpg
#   inflating: open/train/2569.jpg
#   inflating: __MACOSX/open/train/._2569.jpg
#   inflating: open/train/5206.jpg
#   inflating: __MACOSX/open/train/._5206.jpg
#   inflating: open/train/4118.jpg
#   inflating: __MACOSX/open/train/._4118.jpg
#   inflating: open/train/3677.jpg
#   inflating: __MACOSX/open/train/._3677.jpg
#   inflating: open/train/1060.jpg
#   inflating: __MACOSX/open/train/._1060.jpg
#   inflating: open/train/1706.jpg
#   inflating: __MACOSX/open/train/._1706.jpg
#   inflating: open/train/0418.jpg
#   inflating: __MACOSX/open/train/._0418.jpg
#   inflating: open/train/3111.jpg
#   inflating: __MACOSX/open/train/._3111.jpg
#   inflating: open/train/5560.jpg
#   inflating: __MACOSX/open/train/._5560.jpg
#   inflating: open/train/3105.jpg
#   inflating: __MACOSX/open/train/._3105.jpg
#   inflating: open/train/5574.jpg
#   inflating: __MACOSX/open/train/._5574.jpg
#   inflating: open/train/1712.jpg
#   inflating: __MACOSX/open/train/._1712.jpg
#   inflating: open/train/1074.jpg
#   inflating: __MACOSX/open/train/._1074.jpg
#   inflating: open/train/5212.jpg
#   inflating: __MACOSX/open/train/._5212.jpg
#   inflating: open/train/3663.jpg
#   inflating: __MACOSX/open/train/._3663.jpg
#   inflating: open/train/3924.jpg
#   inflating: __MACOSX/open/train/._3924.jpg
#   inflating: open/train/4093.jpg
#   inflating: __MACOSX/open/train/._4093.jpg
#   inflating: open/train/0593.jpg
#   inflating: __MACOSX/open/train/._0593.jpg
#   inflating: open/train/1855.jpg
#   inflating: __MACOSX/open/train/._1855.jpg
#   inflating: open/train/2384.jpg
#   inflating: __MACOSX/open/train/._2384.jpg
#   inflating: open/train/4939.jpg
#   inflating: __MACOSX/open/train/._4939.jpg
# ...
#   inflating: open/train/3399.jpg
#   inflating: __MACOSX/open/train/._3399.jpg
#   inflating: open/train/2938.jpg
#   inflating: __MACOSX/open/train/._2938.jpg
#   inflating: open/train/4391.jpg
#   inflating: __MACOSX/open/train/._4391.jpg
#   inflating: open/train/3398.jpg
#   inflating: __MACOSX/open/train/._3398.jpg
#   inflating: open/train/2086.jpg
#   inflating: __MACOSX/open/train/._2086.jpg
#   inflating: open/train/0849.jpg
#   inflating: __MACOSX/open/train/._0849.jpg
#   inflating: open/train/0691.jpg
#   inflating: __MACOSX/open/train/._0691.jpg
#   inflating: open/train/0685.jpg
#   inflating: __MACOSX/open/train/._0685.jpg
#   inflating: open/train/2092.jpg
#   inflating: __MACOSX/open/train/._2092.jpg
#   inflating: open/train/4385.jpg
#   inflating: __MACOSX/open/train/._4385.jpg
#   inflating: open/train/2904.jpg
#   inflating: __MACOSX/open/train/._2904.jpg
#   inflating: open/train/0875.jpg
#   inflating: __MACOSX/open/train/._0875.jpg
#   inflating: open/train/0861.jpg
#   inflating: __MACOSX/open/train/._0861.jpg
#   inflating: open/train/2910.jpg
#   inflating: __MACOSX/open/train/._2910.jpg
#   inflating: open/train/4352.jpg
#   inflating: __MACOSX/open/train/._4352.jpg
#   inflating: open/train/2723.jpg
#   inflating: __MACOSX/open/train/._2723.jpg
#   inflating: open/train/0134.jpg
#   inflating: __MACOSX/open/train/._0134.jpg
#   inflating: open/train/0652.jpg
#   inflating: __MACOSX/open/train/._0652.jpg
#   inflating: open/train/2045.jpg
#   inflating: __MACOSX/open/train/._2045.jpg
#   inflating: open/train/4434.jpg
#   inflating: __MACOSX/open/train/._4434.jpg
#   inflating: open/train/2051.jpg
#   inflating: __MACOSX/open/train/._2051.jpg
#   inflating: open/train/4420.jpg
#   inflating: __MACOSX/open/train/._4420.jpg
#   inflating: open/train/0646.jpg
#   inflating: __MACOSX/open/train/._0646.jpg
#   inflating: open/train/1558.jpg
#   inflating: __MACOSX/open/train/._1558.jpg
#   inflating: open/train/0120.jpg
#   inflating: __MACOSX/open/train/._0120.jpg
#   inflating: open/train/3429.jpg
#   inflating: __MACOSX/open/train/._3429.jpg
#   inflating: open/train/4346.jpg
#   inflating: __MACOSX/open/train/._4346.jpg
#   inflating: open/train/5058.jpg
#   inflating: __MACOSX/open/train/._5058.jpg
#   inflating: open/train/2737.jpg
#   inflating: __MACOSX/open/train/._2737.jpg
#   inflating: open/train/1216.jpg
#   inflating: __MACOSX/open/train/._1216.jpg
#   inflating: open/train/0108.jpg
#   inflating: __MACOSX/open/train/._0108.jpg
#   inflating: open/train/3401.jpg
#   inflating: __MACOSX/open/train/._3401.jpg
#   inflating: open/train/5070.jpg
#   inflating: __MACOSX/open/train/._5070.jpg
#   inflating: open/train/2079.jpg
#   inflating: __MACOSX/open/train/._2079.jpg
#   inflating: open/train/5716.jpg
#   inflating: __MACOSX/open/train/._5716.jpg
#   inflating: open/train/4408.jpg
#   inflating: __MACOSX/open/train/._4408.jpg
#   inflating: open/train/3367.jpg
#   inflating: __MACOSX/open/train/._3367.jpg
#   inflating: open/train/1570.jpg
#   inflating: __MACOSX/open/train/._1570.jpg
#   inflating: open/train/1564.jpg
#   inflating: __MACOSX/open/train/._1564.jpg
#   inflating: open/train/5702.jpg
#   inflating: __MACOSX/open/train/._5702.jpg
#   inflating: open/train/3373.jpg
#   inflating: __MACOSX/open/train/._3373.jpg
#   inflating: open/train/3415.jpg
#   inflating: __MACOSX/open/train/._3415.jpg
#   inflating: open/train/5064.jpg
#   inflating: __MACOSX/open/train/._5064.jpg
#   inflating: open/train/1202.jpg
#   inflating: __MACOSX/open/train/._1202.jpg
#   inflating: open/train/1955.jpg
#   inflating: __MACOSX/open/train/._1955.jpg
#   inflating: open/train/0493.jpg
#   inflating: __MACOSX/open/train/._0493.jpg
#   inflating: open/train/2284.jpg
#   inflating: __MACOSX/open/train/._2284.jpg
#   inflating: open/train/4193.jpg
#   inflating: __MACOSX/open/train/._4193.jpg
#   inflating: open/train/3824.jpg
#   inflating: __MACOSX/open/train/._3824.jpg
#   inflating: open/train/4187.jpg
#   inflating: __MACOSX/open/train/._4187.jpg
#   inflating: open/train/5299.jpg
#   inflating: __MACOSX/open/train/._5299.jpg
#   inflating: open/train/3830.jpg
#   inflating: __MACOSX/open/train/._3830.jpg
#   inflating: open/train/4839.jpg
#   inflating: __MACOSX/open/train/._4839.jpg
#   inflating: open/train/2290.jpg
#   inflating: __MACOSX/open/train/._2290.jpg
#   inflating: open/train/1941.jpg
#   inflating: __MACOSX/open/train/._1941.jpg
#   inflating: open/train/0487.jpg
#   inflating: __MACOSX/open/train/._0487.jpg
#   inflating: open/train/1799.jpg
#   inflating: __MACOSX/open/train/._1799.jpg
#   inflating: open/train/4811.jpg
#   inflating: __MACOSX/open/train/._4811.jpg
#   inflating: open/train/1969.jpg
#   inflating: __MACOSX/open/train/._1969.jpg
#   inflating: open/train/3818.jpg
#   inflating: __MACOSX/open/train/._3818.jpg
#   inflating: open/train/4805.jpg
#   inflating: __MACOSX/open/train/._4805.jpg
#   inflating: open/train/3159.jpg
#   inflating: __MACOSX/open/train/._3159.jpg
#   inflating: open/train/4636.jpg
#   inflating: __MACOSX/open/train/._4636.jpg
#   inflating: open/train/5528.jpg
#   inflating: __MACOSX/open/train/._5528.jpg
#   inflating: open/train/2247.jpg
#   inflating: __MACOSX/open/train/._2247.jpg
#   inflating: open/train/1996.jpg
#   inflating: __MACOSX/open/train/._1996.jpg
#   inflating: open/train/0450.jpg
#   inflating: __MACOSX/open/train/._0450.jpg
#   inflating: open/train/0336.jpg
#   inflating: __MACOSX/open/train/._0336.jpg
#   inflating: open/train/1028.jpg
#   inflating: __MACOSX/open/train/._1028.jpg
#   inflating: open/train/2521.jpg
#   inflating: __MACOSX/open/train/._2521.jpg
#   inflating: open/train/4150.jpg
#   inflating: __MACOSX/open/train/._4150.jpg
#   inflating: open/train/2535.jpg
#   inflating: __MACOSX/open/train/._2535.jpg
#   inflating: open/train/4144.jpg
#   inflating: __MACOSX/open/train/._4144.jpg
#   inflating: open/train/0322.jpg
#   inflating: __MACOSX/open/train/._0322.jpg
#   inflating: open/train/1982.jpg
#   inflating: __MACOSX/open/train/._1982.jpg
#   inflating: open/train/0444.jpg
#   inflating: __MACOSX/open/train/._0444.jpg
#   inflating: open/train/4622.jpg
#   inflating: __MACOSX/open/train/._4622.jpg
#   inflating: open/train/2253.jpg
#   inflating: __MACOSX/open/train/._2253.jpg
#   inflating: open/train/1772.jpg
#   inflating: __MACOSX/open/train/._1772.jpg
#   inflating: open/train/3165.jpg
#   inflating: __MACOSX/open/train/._3165.jpg
#   inflating: open/train/5514.jpg
#   inflating: __MACOSX/open/train/._5514.jpg
#   inflating: open/train/5272.jpg
#   inflating: __MACOSX/open/train/._5272.jpg
#   inflating: open/train/3603.jpg
#   inflating: __MACOSX/open/train/._3603.jpg
#   inflating: open/train/1014.jpg
#   inflating: __MACOSX/open/train/._1014.jpg
#   inflating: open/train/1000.jpg
#   inflating: __MACOSX/open/train/._1000.jpg
#   inflating: open/train/2509.jpg
#   inflating: __MACOSX/open/train/._2509.jpg
#   inflating: open/train/5266.jpg
#   inflating: __MACOSX/open/train/._5266.jpg
#   inflating: open/train/4178.jpg
#   inflating: __MACOSX/open/train/._4178.jpg
#   inflating: open/train/3617.jpg
#   inflating: __MACOSX/open/train/._3617.jpg
#   inflating: open/train/3171.jpg
#   inflating: __MACOSX/open/train/._3171.jpg
#   inflating: open/train/5500.jpg
#   inflating: __MACOSX/open/train/._5500.jpg
#   inflating: open/train/1766.jpg
#   inflating: __MACOSX/open/train/._1766.jpg
#   inflating: open/train/0478.jpg
#   inflating: __MACOSX/open/train/._0478.jpg
#   inflating: open/train/1821.jpg
#   inflating: __MACOSX/open/train/._1821.jpg
#   inflating: open/train/4781.jpg
#   inflating: __MACOSX/open/train/._4781.jpg
#   inflating: open/train/4959.jpg
#   inflating: __MACOSX/open/train/._4959.jpg
#   inflating: open/train/3950.jpg
#   inflating: __MACOSX/open/train/._3950.jpg
#   inflating: open/train/2496.jpg
#   inflating: __MACOSX/open/train/._2496.jpg
#   inflating: open/train/3788.jpg
#   inflating: __MACOSX/open/train/._3788.jpg
#   inflating: open/train/0281.jpg
#   inflating: __MACOSX/open/train/._0281.jpg
#   inflating: open/train/0295.jpg
#   inflating: __MACOSX/open/train/._0295.jpg
#   inflating: open/train/3944.jpg
#   inflating: __MACOSX/open/train/._3944.jpg
#   inflating: open/train/2482.jpg
#   inflating: __MACOSX/open/train/._2482.jpg
#   inflating: open/train/4795.jpg
#   inflating: __MACOSX/open/train/._4795.jpg
#   inflating: open/train/1835.jpg
#   inflating: __MACOSX/open/train/._1835.jpg
#   inflating: open/train/4965.jpg
#   inflating: __MACOSX/open/train/._4965.jpg
#   inflating: open/train/3978.jpg
#   inflating: __MACOSX/open/train/._3978.jpg
#   inflating: open/train/1809.jpg
#   inflating: __MACOSX/open/train/._1809.jpg
#   inflating: open/train/4971.jpg
#   inflating: __MACOSX/open/train/._4971.jpg
#   inflating: open/train/2333.jpg
#   inflating: __MACOSX/open/train/._2333.jpg
#   inflating: open/train/4742.jpg
#   inflating: __MACOSX/open/train/._4742.jpg
#   inflating: open/train/0524.jpg
#   inflating: __MACOSX/open/train/._0524.jpg
#   inflating: open/train/0242.jpg
#   inflating: __MACOSX/open/train/._0242.jpg
#   inflating: open/train/4024.jpg
#   inflating: __MACOSX/open/train/._4024.jpg
#   inflating: open/train/3993.jpg
#   inflating: __MACOSX/open/train/._3993.jpg
#   inflating: open/train/2455.jpg
#   inflating: __MACOSX/open/train/._2455.jpg
#   inflating: open/train/4030.jpg
#   inflating: __MACOSX/open/train/._4030.jpg
#   inflating: open/train/3987.jpg
#   inflating: __MACOSX/open/train/._3987.jpg
#   inflating: open/train/2441.jpg
#   inflating: __MACOSX/open/train/._2441.jpg
#   inflating: open/train/1148.jpg
#   inflating: __MACOSX/open/train/._1148.jpg
#   inflating: open/train/0256.jpg
#   inflating: __MACOSX/open/train/._0256.jpg
#   inflating: open/train/0530.jpg
#   inflating: __MACOSX/open/train/._0530.jpg
#   inflating: open/train/2327.jpg
#   inflating: __MACOSX/open/train/._2327.jpg
#   inflating: open/train/5448.jpg
#   inflating: __MACOSX/open/train/._5448.jpg
#   inflating: open/train/4756.jpg
#   inflating: __MACOSX/open/train/._4756.jpg
#   inflating: open/train/3039.jpg
#   inflating: __MACOSX/open/train/._3039.jpg
#   inflating: open/train/0518.jpg
#   inflating: __MACOSX/open/train/._0518.jpg
#   inflating: open/train/1606.jpg
#   inflating: __MACOSX/open/train/._1606.jpg
#   inflating: open/train/5460.jpg
#   inflating: __MACOSX/open/train/._5460.jpg
#   inflating: open/train/3011.jpg
#   inflating: __MACOSX/open/train/._3011.jpg
#   inflating: open/train/3777.jpg
#   inflating: __MACOSX/open/train/._3777.jpg
#   inflating: open/train/4018.jpg
#   inflating: __MACOSX/open/train/._4018.jpg
#   inflating: open/train/5306.jpg
#   inflating: __MACOSX/open/train/._5306.jpg
#   inflating: open/train/2469.jpg
#   inflating: __MACOSX/open/train/._2469.jpg
#   inflating: open/train/1160.jpg
#   inflating: __MACOSX/open/train/._1160.jpg
#   inflating: open/train/1174.jpg
#   inflating: __MACOSX/open/train/._1174.jpg
#   inflating: open/train/3763.jpg
#   inflating: __MACOSX/open/train/._3763.jpg
#   inflating: open/train/5312.jpg
#   inflating: __MACOSX/open/train/._5312.jpg
#   inflating: open/train/5474.jpg
#   inflating: __MACOSX/open/train/._5474.jpg
#   inflating: open/train/3005.jpg
#   inflating: __MACOSX/open/train/._3005.jpg
#   inflating: open/train/1612.jpg
#   inflating: __MACOSX/open/train/._1612.jpg
#   inflating: open/train/0083.jpg
#   inflating: __MACOSX/open/train/._0083.jpg
#   inflating: open/train/2694.jpg
#   inflating: __MACOSX/open/train/._2694.jpg
#   inflating: open/train/5845.jpg
#   inflating: __MACOSX/open/train/._5845.jpg
#   inflating: open/train/4583.jpg
#   inflating: __MACOSX/open/train/._4583.jpg
#   inflating: open/train/0929.jpg
#   inflating: __MACOSX/open/train/._0929.jpg
#   inflating: open/train/5689.jpg
#   inflating: __MACOSX/open/train/._5689.jpg
#   inflating: open/train/5851.jpg
#   inflating: __MACOSX/open/train/._5851.jpg
#   inflating: open/train/4597.jpg
#   inflating: __MACOSX/open/train/._4597.jpg
#   inflating: open/train/2858.jpg
#   inflating: __MACOSX/open/train/._2858.jpg
#   inflating: open/train/2680.jpg
#   inflating: __MACOSX/open/train/._2680.jpg
#   inflating: open/train/1389.jpg
#   inflating: __MACOSX/open/train/._1389.jpg
#   inflating: open/train/0097.jpg
#   inflating: __MACOSX/open/train/._0097.jpg
#   inflating: open/train/2870.jpg
#   inflating: __MACOSX/open/train/._2870.jpg
#   inflating: open/train/0901.jpg
#   inflating: __MACOSX/open/train/._0901.jpg
#   inflating: open/train/5879.jpg
#   inflating: __MACOSX/open/train/._5879.jpg
#   inflating: open/train/0915.jpg
#   inflating: __MACOSX/open/train/._0915.jpg
#   inflating: open/train/2864.jpg
#   inflating: __MACOSX/open/train/._2864.jpg
#   inflating: open/train/2657.jpg
#   inflating: __MACOSX/open/train/._2657.jpg
#   inflating: open/train/5138.jpg
#   inflating: __MACOSX/open/train/._5138.jpg
#   inflating: open/train/4226.jpg
#   inflating: __MACOSX/open/train/._4226.jpg
#   inflating: open/train/3549.jpg
#   inflating: __MACOSX/open/train/._3549.jpg
#   inflating: open/train/0040.jpg
#   inflating: __MACOSX/open/train/._0040.jpg
#   inflating: open/train/1438.jpg
#   inflating: __MACOSX/open/train/._1438.jpg
#   inflating: open/train/0726.jpg
#   inflating: __MACOSX/open/train/._0726.jpg
#   inflating: open/train/5886.jpg
#   inflating: __MACOSX/open/train/._5886.jpg
#   inflating: open/train/4540.jpg
#   inflating: __MACOSX/open/train/._4540.jpg
#   inflating: open/train/2131.jpg
#   inflating: __MACOSX/open/train/._2131.jpg
#   inflating: open/train/5892.jpg
#   inflating: __MACOSX/open/train/._5892.jpg
#   inflating: open/train/4554.jpg
#   inflating: __MACOSX/open/train/._4554.jpg
#   inflating: open/train/2125.jpg
#   inflating: __MACOSX/open/train/._2125.jpg
#   inflating: open/train/0732.jpg
#   inflating: __MACOSX/open/train/._0732.jpg
#   inflating: open/train/0054.jpg
#   inflating: __MACOSX/open/train/._0054.jpg
#   inflating: open/train/2643.jpg
#   inflating: __MACOSX/open/train/._2643.jpg
#   inflating: open/train/4232.jpg
#   inflating: __MACOSX/open/train/._4232.jpg
#   inflating: open/train/1362.jpg
#   inflating: __MACOSX/open/train/._1362.jpg
#   inflating: open/train/5104.jpg
#   inflating: __MACOSX/open/train/._5104.jpg
#   inflating: open/train/3575.jpg
#   inflating: __MACOSX/open/train/._3575.jpg
#   inflating: open/train/3213.jpg
#   inflating: __MACOSX/open/train/._3213.jpg
#   inflating: open/train/5662.jpg
#   inflating: __MACOSX/open/train/._5662.jpg
#   inflating: open/train/1404.jpg
#   inflating: __MACOSX/open/train/._1404.jpg
#   inflating: open/train/1410.jpg
#   inflating: __MACOSX/open/train/._1410.jpg
#   inflating: open/train/3207.jpg
#   inflating: __MACOSX/open/train/._3207.jpg
#   inflating: open/train/4568.jpg
#   inflating: __MACOSX/open/train/._4568.jpg
#   inflating: open/train/5676.jpg
#   inflating: __MACOSX/open/train/._5676.jpg
#   inflating: open/train/2119.jpg
#   inflating: __MACOSX/open/train/._2119.jpg
#   inflating: open/train/5110.jpg
#   inflating: __MACOSX/open/train/._5110.jpg
#   inflating: open/train/3561.jpg
#   inflating: __MACOSX/open/train/._3561.jpg
#   inflating: open/train/0068.jpg
#   inflating: __MACOSX/open/train/._0068.jpg
#   inflating: open/train/1376.jpg
#   inflating: __MACOSX/open/train/._1376.jpg

# %%
import glob
filepaths1 = list(glob.glob('/content/open/test/*.jpg'))
filepaths2 = list(glob.glob('/content/open/train/*.jpg'))
print(len(filepaths1))
print(len(filepaths2))
# Out:
# 12670
# 5911

# %%
# 2. 파이토치 데이터셋 생성

# 현재 작업디렉토리 return
base_dir = os.getcwd() # 기본 디렉토리 경로
data_dir = '/content/open' # 데이터 파일이 있는 디렉토리 경로

df = pd.read_csv(f'{data_dir}/train.csv')
df1 = pd.read_csv(f'{data_dir}/train.csv')

df.head()
# Out:
#    id          img_path            artist
# 0   0  ./train/0000.jpg   Diego Velazquez
# 1   1  ./train/0001.jpg  Vincent van Gogh
# 2   2  ./train/0002.jpg      Claude Monet
# 3   3  ./train/0003.jpg       Edgar Degas
# 4   4  ./train/0004.jpg  Hieronymus Bosch

# %%
# Label Encoding
le = preprocessing.LabelEncoder()
df['artist'] = le.fit_transform(df['artist'].values) # artist를 정수 형태로

df.head()
# Out:
#    id          img_path  artist
# 0   0  ./train/0000.jpg       9
# 1   1  ./train/0001.jpg      48
# 2   2  ./train/0002.jpg       7
# 3   3  ./train/0003.jpg      10
# 4   4  ./train/0004.jpg      24

# %%
# 데이터 train, test 나누기 (데이터의 20%를 testset)
train_df, val_df, _, _ = train_test_split(df, df['artist'].values, test_size=0.2, random_state=CFG['SEED'])

# %%
# 'train_df'를 'id' 열 기준으로 정렬
train_df = train_df.sort_values(by=['id'])
train_df.head()
# Out:
#    id          img_path  artist
# 0   0  ./train/0000.jpg       9
# 2   2  ./train/0002.jpg       7
# 3   3  ./train/0003.jpg      10
# 5   5  ./train/0005.jpg      38
# 6   6  ./train/0006.jpg      43

# %%
# val_df'를 'id' 열 기준으로 정렬
val_df = val_df.sort_values(by=['id'])
val_df.head()
# Out:
#     id          img_path  artist
# 1    1  ./train/0001.jpg      48
# 4    4  ./train/0004.jpg      24
# 17  17  ./train/0017.jpg      10
# 21  21  ./train/0021.jpg      29
# 29  29  ./train/0029.jpg      28

# %%
def get_data(df, infer=False):
  if infer:
    return df['img_path'].values # img_path return
  return df['img_path'].values, df['artist'].values # img_path, artist return

train_img_paths, train_labels = get_data(train_df) # train
val_img_paths, val_labels = get_data(val_df) # test

print(f"{data_dir}/{train_img_paths[0].split('/')[-2]}/{train_img_paths[0].split('/')[-1]}")
# Out:
# /content/open/train/0000.jpg

# %%
class CustomDataset(Dataset):
  def __init__(self, img_paths, labels, transforms=None):
    self.img_paths = img_paths
    self.labels = labels
    self.transforms = transforms

  def __getitem__(self, index):
    img_path = self.img_paths[index]
    image = cv2.imread(f"{data_dir}/{img_path.split('/')[-2]}/{img_path.split('/')[-1]}")
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    if self.transforms is not None:
      image = self.transforms(image=image)['image'] # 이미지 변환

    if self.labels is not None:
      label = self.labels[index]
      return image, label
    else:
      return image

  # 총 데이터 수
  def __len__(self):
    return len(self.img_paths)

# 이미지 크기 조정
def resize_transform(size, state='train'):
  if state == 'train':
    transform = A.Compose([
        A.HorizontalFlip(p=0.5),
        A.VerticalFlip(p=0.5),
        A.Rotate(p=0.5),
        A.RandomRotate90(p=0.5),
        A.RandomResizedCrop(height=size, width=size, scale=(0.3,1.0)),
        A.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
        ToTensorV2(),
    ])
  else:
    transform = A.Compose([
        A.Resize(size, size),
        A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), max_pixel_value=255.0, always_apply=False, p=1.0),
        ToTensorV2()
    ])

  return transform
# 256, 288, 320, 384, 456, 528
# 240, 260, 300, 380, 456, 528

# %%
# 3. 파이토치 모델 만들기
class BaseModel(nn.Module): # 모델이 224 픽셀 크기의 이미지에 사용될 것 # torch.nn.Module 은 PyTorch의 모든 Neural Network의 Base Class
  def __init__(self, num_classes=len(le.classes_)):
    super(BaseModel, self).__init__() # 모델 초기화
    self.backbone = models.efficientnet_b0(pretrained=True) # 이미지 특성 추출

    self.classifier = nn.Sequential(nn.ReLU(), # EfficientNet의 출력 특성을 받아서 최종 클래스 예측을 수행
                                    nn.Dropout(),
                                    nn.Linear(1000, num_classes))

  def forward(self, x):
    x = self.backbone(x)
    x = self.classifier(x)
    return x # 최종 클래스 예측 결과

class EfficientNet_B1(nn.Module): # 256
  def __init__(self, num_classes=len(le.classes_)):
    super(EfficientNet_B1, self).__init__()
    self.backbone = models.efficientnet_b1(pretrained=True)

    self.classifier = nn.Sequential(nn.ReLU(),
                                    nn.Dropout(),
                                    nn.Linear(1000, num_classes))

  def forward(self, x):
    x = self.backbone(x)
    x = self.classifier(x)
    return x

class EfficientNet_B2(nn.Module): # 288
  def __init__(self, num_classes=len(le.classes_)):
    super(EfficientNet_B2, self).__init__()
    self.backbone = models.efficientnet_b2(pretrained=True)

    self.classifier = nn.Sequential(nn.ReLU(),
                                    nn.Dropout(),
                                    nn.Linear(1000, num_classes))

  def forward(self, x):
    x = self.backbone(x)
    x = self.classifier(x)
    return x

class EfficientNet_B3(nn.Module): # 320
  def __init__(self, num_class=len(le.classes_)):
    super(EfficientNet_B3, self).__init__()
    self.backbone = models.efficientnet_b3(pretrained=True)

    self.classifier = nn.Sequential(nn.ReLU(),
                                    nn.Dropout(),
                                    nn.Linear(1000, num_classes))

  def forward(self, x):
    x = self.backbone(x)
    x = self.classifier(x)
    return x

class EfficientNet_B4(nn.Module): # 384
  def __init__(self, num_classes=len(le.classes_)):
    super(EfficientNet_B4, self).__init__()
    self.backbone = models.efficientnet_b4(pretrained=True)

    self.classifier = nn.Sequential(nn.ReLU(),
                                    nn.Dropout(),
                                    nn.Linear(1000, num_classes))

  def forward(self, x):
    x = self.backbone(x)
    x = self.classifier(x)
    return x

class EfficientNet_B5(nn.Module): # 456
  def __init__(self, num_classes=len(le.classes_)):
    super(EfficientNet_B5, self).__init__()
    self.backbone = models.efficientnet_b5(pretrained=True)

    self.classifier = nn.Sequential(nn.ReLU(),
                                    nn.Dropout(),
                                    nn.Linear(1000, num_classes))

  def forward(self, x):
    x = self.backbone(x)
    x = self.classifier(x)
    return x

class EfficientNet_B6(nn.Module):
  def __init__(self, num_classes=len(le.classes_)):
    super(EfficientNet_B6, self).__init__()
    self.backbone = models.efficientnet_b6(pretrained=True)

    self.classifier = nn.Sequential(nn.ReLU(),
                                    nn.Dropout(),
                                    nn.Linear(1000, num_classes))

  def forawrd(self, x):
    x = self.backbone(x)
    x = self.classifier(x)
    return x

class EfficientNet_Bn(nn.Module):
    def __init__(self, num_classes=len(le.classes_), b_num=0):
        super(EfficientNet_Bn, self).__init__()
        self.backbone = EfficientNet.from_pretrained(f'efficientnet-b{b_num}')

        self.classifier = nn.Sequential(
                                        nn.ReLU(),
                                        nn.Dropout(),
                                        nn.Linear(1000, num_classes))
    def forward(self, x):
        x = self.backbone(x)
        x = self.classifier(x)
        return x

# %%
# 4. 모델 Train
def train(model, epochs, optimizer, train_loader, test_loader, scheduler, device):
  model.to(device) # 모델을 지정한 장치 (CPU 또는 GPU)로 이동

  criterion = nn.CrossEntropyLoss().to(device) # 손실 함수 (CrossEntropyLoss)

  best_score = 0 # 현재까지 관찰된 가장 높은 검증 성능
  best_model = None # 현재까지 관찰된 최고 성능을 달성한 모델

  for epoch in range(1, epochs+1):
    model.train() # 모델을 학습 모드로 설정
    train_loss = [] # 각 에폭에서 학습 데이터에 대한 손실을 추적
    # 학습 데이터셋을 순회하며 모델을 학습
    for img, label in tqdm(iter(train_loader)):
      img, label = img.float().to(device), label.type(torch.LongTensor).to(device) # 이미지와 레이블을 지정한 장치로 이동

      optimizer.zero_grad() # 기울기 초기화

      model_pred = model(img) # 모델의 예측 생성

      loss = criterion(model_pred, label) # 손실 계산

      loss.backward() # 역전파 및 가중치 업데이트
      optimizer.step()

      train_loss.append(loss.item()) # 학습 손실 저장

    tr_loss = np.mean(train_loss) # 학습 손실 평균 계산

    val_loss, val_score = validation(model, criterion, test_loader, device) # 검증 손실과 F1 점수 계산

    print(f'Epoch [{epoch}], Train Loss: [{tr_loss:.5f}] Val Loss: [{val_loss:.5f}] Val F1 Score: [{val_score:.5f}]')  # 에폭별 학습 및 검증 결과 출력

    if scheduler is not None: # 스케줄러가 주어진 경우 학습률 스케줄링 적용
      scheduler.step()

    if best_score < val_score: # 현재까지의 최고 성능을 기록한 경우, 모델 저장
      best_model = model
      best_score = val_score

  return best_model # 최고 성능을 달성한 모델 반환

def competition_metric(true, pred):
  return f1_score(true, pred, average="macro") # F1 점수를 계산하여 반환

def validation(model, criterion, test_loader, device):
  model.eval() # 모델을 평가 모드로 설정

  # 모델의 예측과 실제 레이블을 저장할 리스트
  model_preds = []
  true_labels = []

  val_loss = [] # 검증 손실 저장

  with torch.no_grad():
    # 검증 데이터셋을 순회하며 모델 평가
    for img, label in tqdm(iter(test_loader)):
      img, label = img.float().to(device), label.type(torch.LongTensor).to(device) # 이미지와 레이블을 지정한 장치로 이동

      model_pred = model(img) # 모델의 예측 생성

      # 손실 계산
      loss = criterion(model_pred, label)
      val_loss.append(loss.item())

      # 모델의 예측과 실제 레이블 저장
      model_preds += model_pred.argmax(1).detach().cpu().numpy().tolist()
      true_labels += label.detach().cpu().numpy().tolist()

  # 검증 데이터의 F1 점수 계산
  val_f1 = competition_metric(true_labels, model_preds)

  return np.mean(val_loss), val_f1

num_epoch = 30

# %%
train_dataset_0 = CustomDataset(train_img_paths, train_labels, resize_transform(224,'train')) # trainset 처리하기 위한 사용자 정의 데이터셋 생성
train_loader_0 = DataLoader(train_dataset_0, batch_size=32, shuffle=True, num_workers=0) # 데이터를 배치 단위로 로드

val_dataset_0 = CustomDataset(val_img_paths, val_labels, resize_transform(224,'test')) # testset 처리하기 위한 사용자 정의 데이터셋 생성
val_loader_0 = DataLoader(val_dataset_0, batch_size=32, shuffle=False, num_workers=0) # 데이터를 배치 단위로 로드

model_0 = EfficientNet_Bn(b_num=0) # 모델 초기화
optimizer_0 = torch.optim.Adam(params = model_0.parameters(), lr = CFG["LEARNING_RATE"]) # 모델 가중치 업데이트하는 옵티마이저
scheduler_0 = lr_scheduler.MultiStepLR(optimizer_0, milestones=[10,20], gamma=0.5) # 학습률 스케줄링을 수행하는 스케줄러
infer_model_0 = train(model_0, num_epoch, optimizer_0, train_loader_0, val_loader_0, scheduler_0, device) # 모델을 학습하고 최상의 성능을 달성한 모델
# Out:
# Loaded pretrained weights for efficientnet-b0
#   0%|          | 0/148 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-d2c02ed68691> in <cell line: 10>()
#       8 optimizer_0 = torch.optim.Adam(params = model_0.parameters(), lr = CFG["LEARNING_RATE"]) # 모델 가중치 업데이트하는 옵티마이저
#       9 scheduler_0 = lr_scheduler.MultiStepLR(optimizer_0, milestones=[10,20], gamma=0.5) # 학습률 스케줄링을 수행하는 스케줄러
# ---> 10 infer_model_0 = train(model_0, num_epoch, optimizer_0, train_loader_0, val_loader_0, scheduler_0, device) # 모델을 학습하고 최상의 성능을 달성한 모델
#
# <ipython-input-20-697e4174e23e> in train(model, epochs, optimizer, train_loader, test_loader, scheduler, device)
#      21       loss = criterion(model_pred, label) # 손실 계산
#      22
# ---> 23       loss.backward() # 역전파 및 가중치 업데이트
#      24       optimizer.step()
#      25
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     490                 inputs=inputs,
#     491             )
# --> 492         torch.autograd.backward(
#     493             self, gradient, retain_graph, create_graph, inputs=inputs
#     494         )
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     249     # some Python versions print out the first line of a multi-line function
#     250     # calls in the traceback and some print out the last line
# --> 251     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252         tensors,
#     253         grad_tensors_,
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/function.py in apply(self, *args)
#     274
#     275 class BackwardCFunction(_C._FunctionBase, FunctionCtx, _HookMixin):
# --> 276     def apply(self, *args):
#     277         # _forward_cls is defined by derived class
#     278         # The user should define either backward or vjp but never both.
#
# KeyboardInterrupt:

# %%
torch.save(infer_model_0, 'weights/b0_32_30.pt') # 학습된 모델의 상태를 파일에 저장
gc.collect() # 메모리 관리
torch.cuda.empty_cache() # GPU 메모리 관리

# %%
#0.76917 batch:16, epoch:30, LR:[10,20]
#0.73733 batch:8, epoch:30, LR:[9,19,27]
train_dataset_1 = CustomDataset(train_img_paths, train_labels, resize_transform(256,'train'))
train_loader_1 = DataLoader(train_dataset_1, batch_size=32, shuffle=True, num_workers=0)

val_dataset_1 = CustomDataset(val_img_paths, val_labels, resize_transform(256,'test'))
val_loader_1 = DataLoader(val_dataset_1, batch_size=32, shuffle=False, num_workers=0)

model_1 = EfficientNet_Bn(b_num=1)
optimizer_1 = torch.optim.Adam(params = model_1.parameters(), lr = CFG["LEARNING_RATE"])
scheduler_1 = lr_scheduler.MultiStepLR(optimizer_1, milestones=[10,20], gamma=0.5)
infer_model_1 = train(model_1, num_epoch, optimizer_1, train_loader_1, val_loader_1, scheduler_1, device)
# Out:
# Loaded pretrained weights for efficientnet-b1
#   0%|          | 0/148 [00:00<?, ?it/s]
#   0%|          | 0/37 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-a0d56c6d13cf> in <cell line: 12>()
#      10 optimizer_1 = torch.optim.Adam(params = model_1.parameters(), lr = CFG["LEARNING_RATE"])
#      11 scheduler_1 = lr_scheduler.MultiStepLR(optimizer_1, milestones=[10,20], gamma=0.5)
# ---> 12 infer_model_1 = train(model_1, num_epoch, optimizer_1, train_loader_1, val_loader_1, scheduler_1, device)
#
# <ipython-input-28-3a4ba9616f8f> in train(model, epochs, optimizer, train_loader, test_loader, schedulver, device)
#      28     tr_loss = np.mean(train_loss) # 학습 손실 평균 계산
#      29
# ---> 30     val_loss, val_score = validation(model, criterion, test_loader, device) # 검증 손실과 F1 점수 계산
#      31
#      32     print(f'Epoch [{epoch}], Train Loss: [{tr_loss:.5f}] Val Loss: [{val_loss:.5f}] Val F1 Score: [{val_score:.5f}]')  # 에폭별 학습 및 검증 결과 출력
#
# <ipython-input-28-3a4ba9616f8f> in validation(model, criterion, test_loader, device)
#      71   val_f1 = competition_metric(true_labels, model_preds)
#      72
# ---> 73   return np.mean(val_loss, val_f1)
#      74
#      75 num_epoch = 30
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in mean(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims, where)
#    3430             return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3431
# -> 3432     return _methods._mean(a, axis=axis, dtype=dtype,
#    3433                           out=out, **kwargs)
#    3434
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims, where)
#     166     is_float16_result = False
#     167
# --> 168     rcount = _count_reduce_items(arr, axis, keepdims=keepdims, where=where)
#     169     if rcount == 0 if where is True else umr_any(rcount == 0, axis=None):
#     170         warnings.warn("Mean of empty slice.", RuntimeWarning, stacklevel=2)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py in _count_reduce_items(arr, axis, keepdims, where)
#      74         items = 1
#      75         for ax in axis:
# ---> 76             items *= arr.shape[mu.normalize_axis_index(ax, arr.ndim)]
#      77         items = nt.intp(items)
#      78     else:
#
# TypeError: integer argument expected, got float

# %%
torch.save(infer_model_1, 'weights/b1_32_39.pt')
gc.collect()
torch.cuda.empty_cache()

# %%
#0.78464 batch:16, epoch:30, LR:[10,20]
#0.77673 batch:8, epoch:30, LR:[9,18,27]
train_dataset_2 = CustomDataset(train_img_paths, train_labels, resize_transform(288,'train'))
train_loader_2 = DataLoader(train_dataset_2, batch_size=32, shuffle=True, num_workers=0)

val_dataset_2 = CustomDataset(val_img_paths, val_labels, resize_transform(299,'test'))
val_loader_2 = DataLoader(val_dataset_2, batch_size=32, shuffle=False, num_workers=0)

model_2 = EfficientNet_Bn(b_num=2)
optimizer_2 = torch.optim.Adam(params = model_2.parameters(), lr = CFG["LEARNING_RATE"])
scheduler_2 = lr_scheduler.MultiStepLR(optimizer_2, milestones=[10,20], gamma=0.5)
infer_model_2 = train(model_2, num_epoch, optimizer_2, train_loader_2, val_loader_2, scheduler_2, device)

# %%
torch.save(infer_model_2, 'weights/b2_32_30.pt')
gc.collect()
torch.cuda.empty_cache()

# %%
# 0.77395 batch:32, epoch:30, LR: [10,20]
# 0.77227 batch:16, epcoh:30, lr:[10,20]
# 0.76952 batch:8, epoch:30, LR: [9,18,27]
train_dataset_3 = CustomDataset(train_img_paths, train_labels, resize_transform(320,'train'))
train_loader_3 = DataLoader(train_dataset_3, batch_size=32, shuffle=True, num_workers=0)

val_dataset_3 = CustomDataset(val_img_paths, val_labels, resize_transform(320,'test'))
val_loader_3 = DataLoader(val_dataset_3, batch_size=32, shuffle=False, num_workers=0)

model_3 = EfficientNet_Bn(b_num=3)
optimizer_3 = torch.optim.Adam(params = model_3.parameters(), lr = CFG["LEARNING_RATE"])
scheduler_3 = lr_scheduler.MultiStepLR(optimizer_3, milestones=[10,20], gamma=0.5)
infer_model_3 = train(model_3, num_epoch, optimizer_3, train_loader_3, val_loader_3, scheduler_3, device)

# %%
torch.save(infer_model_3, 'weights/b3_32_30.pt')
gc.collect()
torch.cuda.empty_cache()

# %%
#0.79137 batch:16, epoch:30, lr[10,20]
#0.79599 batch:8, epoch:30, LR: [9,18,27]
train_dataset_4 = CustomDataset(train_img_paths, train_labels, resize_transform(384,'train'))
train_loader_4 = DataLoader(train_dataset_4, batch_size=16, shuffle=True, num_workers=0)

val_dataset_4 = CustomDataset(val_img_paths, val_labels, resize_transform(384,'test'))
val_loader_4 = DataLoader(val_dataset_4, batch_size=16, shuffle=False, num_workers=0)

model_4 = EfficientNet_Bn(b_num=4)
optimizer_4 = torch.optim.Adam(params = model_4.parameters(), lr = CFG["LEARNING_RATE"])
scheduler_4 = lr_scheduler.MultiStepLR(optimizer_4, milestones=[10,20], gamma=0.5)
infer_model_4 = train(model_4, num_epoch, optimizer_4, train_loader_4, val_loader_4, scheduler_4, device)

# %%
torch.save(infer_model_4,'weights/b4_16_30.pt')
gc.collect()
torch.cuda.empty_cache()

# %%
#0.82004 batch:8, epoch : 30, lr:[9,18,27]
train_dataset_5 = CustomDataset(train_img_paths, train_labels, resize_transform(456,'train'))
train_loader_5 = DataLoader(train_dataset_5, batch_size=8, shuffle=True, num_workers=0)

val_dataset_5 = CustomDataset(val_img_paths, val_labels, resize_transform(456,'test'))
val_loader_5 = DataLoader(val_dataset_5, batch_size=8, shuffle=False, num_workers=0)

model_5 = EfficientNet_Bn(b_num=5)
optimizer_5 = torch.optim.Adam(params = model_5.parameters(), lr = CFG["LEARNING_RATE"])
scheduler_5 = lr_scheduler.MultiStepLR(optimizer_5, milestones=[10,20], gamma=0.5)
infer_model_5 = train(model_5, num_epoch, optimizer_5, train_loader_5, val_loader_5, scheduler_5, device)

# %%
torch.save(infer_model_5,'weights/b5_8_30.pt')
gc.collect()
torch.cuda.empty_cache()

# %%
#0.80073 batch:4, epoch:30, lr:[8,16,24]
train_dataset_6 = CustomDataset(train_img_paths, train_labels, resize_transform(528,'train'))
train_loader_6 = DataLoader(train_dataset_6, batch_size=4, shuffle=True, num_workers=0)

val_dataset_6 = CustomDataset(val_img_paths, val_labels, resize_transform(528,'test'))
val_loader_6 = DataLoader(val_dataset_6, batch_size=4, shuffle=False, num_workers=0)

model_6 = EfficientNet_Bn(b_num=6)
optimizer_6 = torch.optim.Adam(params = model_6.parameters(), lr = CFG["LEARNING_RATE"])
scheduler = lr_scheduler.MultiStepLR(optimizer_6, milestones=[10,20], gamma=0.5)
infer_model_6 = train(model_6,num_epoch, optimizer_6, train_loader_6, val_loader_6, scheduler, device)

# %%
torch.save(infer_model_6,'weights/b6_4_30.pt')
gc.collect()
torch.cuda.empty_cache()

# %%
# 5.모델 Test
test_df = pd.read_csv(f'{data_dir}/test.csv')
test_df.head()

# %%
test_img_paths = get_data(test_df, infer=True)

test_dataset_1 = CustomDataset(test_img_paths, None, resize_transform(256,'test'))
test_loader_1 = DataLoader(test_dataset_1, batch_size=CFG['BATCH_SIZE'], shuffle=False, num_workers=0)

test_dataset_2 = CustomDataset(test_img_paths, None, resize_transform(288,'test'))
test_loader_2 = DataLoader(test_dataset_2, batch_size=CFG['BATCH_SIZE'], shuffle=False, num_workers=0)

test_dataset_3 = CustomDataset(test_img_paths, None, resize_transform(320,'test'))
test_loader_3 = DataLoader(test_dataset_3, batch_size=CFG['BATCH_SIZE'], shuffle=False, num_workers=0)

test_dataset_4 = CustomDataset(test_img_paths, None, resize_transform(384,'test'))
test_loader_4 = DataLoader(test_dataset_4, batch_size=16, shuffle=False, num_workers=0)

test_dataset_5 = CustomDataset(test_img_paths, None, resize_transform(456,'test'))
test_loader_5 = DataLoader(test_dataset_5, batch_size=16, shuffle=False, num_workers=0)

test_dataset_6 = CustomDataset(test_img_paths, None, resize_transform(528,'test'))
test_loader_6 = DataLoader(test_dataset_6, batch_size=8, shuffle=False, num_workers=0)

# %%
# Inference Test
def inference(model, test_loader, device):
  model.to(device)
  model.eval()

  model_preds = []

  with torch.no_grad():
    for img in tqdm(iter(test_loader)):
      img = img.float().to(device)

      model_pred = model(img)
      model_preds += model_pred.detach().cpu().numpy().tolist()

  print('Done.')
  return model_preds

#preds = inference(infer_model_5, test_loader_5, device)
